# %%
#https://github.com/wolverton-research-group/qmpy/blob/master/qmpy/data/thermodata/ssub.dat
import pandas as pd
df=pd.read_csv('ssub.dat',sep=' ',header=None)
df.columns=['formula','formula_energy']

# %%
df
# Out:
#          formula  formula_energy
# 0       AlKO6Si2   -3.144727e+00
# 1     Al2H4O9Si2   -2.500142e+00
# 2     Al2H4O9Si2   -2.499380e+00
# 3          AlHO2   -2.589914e+00
# 4          AlHO2   -2.566077e+00
# ...          ...             ...
# 2085         AsS   -1.763221e-01
# 2086      As7Re3   -9.887016e-02
# 2087     As8Ni11   -4.222273e-01
# 2088          Au    1.605726e-09
# 2089        AuBr   -7.371898e-02
#
# [2090 rows x 2 columns]

# %%
#https://stackoverflow.com/questions/12497402/remove-duplicates-by-columns-a-keeping-the-row-with-the-highest-value-in-column
df=df.sort_values('formula_energy', ascending=True).drop_duplicates('formula').sort_index()
df=df.sample(frac=1)
df['id']=df.index

# %%
df
# Out:
#        formula  formula_energy    id
# 1982    AsK3O4       -2.161922  1982
# 517     CdN2O6       -0.526223   517
# 1800    Re5Si3       -0.203811  1800
# 787       CrSi       -0.367932   787
# 2025      B2V3       -0.629646  2025
# ...        ...             ...   ...
# 1349   Li2O3Si       -2.849311  1349
# 1621      O2Se       -0.779048  1621
# 1705  O5Rb2Si2       -2.849610  1705
# 1684   O4Pb2Si       -2.040088  1684
# 1859     SiZr3       -0.631754  1859
#
# [1727 rows x 3 columns]

# %%
df.to_csv('ssub.csv',index=False)

# %%
from jarvis.db.jsonutils import dumpjson
#for jarvis-tools
mem=[]
for i,ii in df.iterrows():
    info={}
    info['id']=ii['id']
    info['formula_energy']=ii['formula_energy']
    info['formula']=ii['formula']
    mem.append(info)
dumpjson(filename='ssub.json',data=mem)

# %%
test_size = 0.2
val_size = 0.2
n_train = int(len(df)*(1-(val_size+test_size)))
n_val = int(len(df)*val_size)
n_test = int(len(df)*test_size)
#for leaderboard
mem={}
train={}
val={}
test={}
train_df = df[:n_train]
val_df = df[n_train:n_train+n_val]
test_df = df[n_train+n_val:n_train+n_val+n_test]
for i,ii in train_df.iterrows():
    train[str(ii['id'])]=ii['formula_energy']
for i,ii in val_df.iterrows():
    val[str(ii['id'])]=ii['formula_energy']
for i,ii in test_df.iterrows():
    test[str(ii['id'])]=ii['formula_energy']
mem['train']=train
mem['val']=val
mem['test']=test
fname='ssub_formula_energy.json'
dumpjson(data=mem,filename=fname)

# %%
len(train_df), len(val_df), len(test_df)
# Out:
# (1036, 345, 345)

# %%
import data_utils
from jarvis.ai.descriptors.elemental import get_element_fraction_desc
from jarvis.ai.descriptors.cfid import CFID,get_chem_only_descriptors
from tqdm import tqdm
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

elements = ['H', 'Li', 'Be', 'B', 'C', 'N', 'O', 'F', 'Na', 'Mg', 'Al', 'Si', 'P', 'S', 'Cl', 'K',
 'Ca', 'Sc', 'Ti', 'V', 'Cr', 'Mn', 'Fe', 'Co', 'Ni', 'Cu', 'Zn', 'Ga', 'Ge', 'As', 'Se',
 'Br', 'Kr', 'Rb', 'Sr', 'Y', 'Zr', 'Nb', 'Mo', 'Tc', 'Ru', 'Rh', 'Pd', 'Ag', 'Cd', 'In',
 'Sn', 'Sb', 'Te', 'I', 'Xe', 'Cs', 'Ba', 'La', 'Ce', 'Pr', 'Nd', 'Pm', 'Sm', 'Eu', 'Gd',
 'Tb', 'Dy', 'Ho', 'Er', 'Tm', 'Yb', 'Lu', 'Hf', 'Ta', 'W', 'Re', 'Os', 'Ir', 'Pt', 'Au',
 'Hg', 'Tl', 'Pb', 'Bi', 'Ac','Th', 'Pa', 'U', 'Np', 'Pu']

def formula_to_ef(df):
    df['comp_dict'] = df['formula'].apply(lambda x: data_utils.parse_formula(x))
    df['comp_fractions'] = df['comp_dict'].apply(lambda x: data_utils.get_fractions(x))
    df = df[~df['comp_fractions'].isnull()]

    for i,e in enumerate(elements):
        df[e] = [ x[i] for x in df['comp_fractions']]

    X_df = np.array(df[elements],dtype='float')    
    y_df = np.array(df['formula_energy'],dtype='float')
    list_df = list(df['id'])

    return X_df, y_df, list_df

# %%
X_train, y_train, train_ids = formula_to_ef(train_df)
X_val, y_val, val_ids = formula_to_ef(val_df)
X_test, y_test, test_ids = formula_to_ef(test_df)
# Out:
# /tmp/ipykernel_63858/1972034185.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['comp_dict'] = df['formula'].apply(lambda x: data_utils.parse_formula(x))
# /tmp/ipykernel_63858/1972034185.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['comp_fractions'] = df['comp_dict'].apply(lambda x: data_utils.get_fractions(x))
# /tmp/ipykernel_63858/1972034185.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[e] = [ x[i] for x in df['comp_fractions']]

# %%
import numpy as np
np.random.seed(1234567)
import tensorflow as tf
tf.random.set_seed(1234567)
import random
random.seed(1234567)

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LeakyReLU
from tensorflow.keras.layers import Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Activation
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import mean_absolute_error, mean_squared_error
# Out:
# 2023-05-14 17:43:01.267066: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %%
#Network from "Cross-property deep transfer learning framework for enhanced predictive analytics on small materials data"
#Link to paper: https://www.nature.com/articles/s41467-021-26921-5
in_layer = Input(shape=(X_train.shape[1],))

layer_1 = Dense(1024)(in_layer)
layer_1 = Activation('relu')(layer_1)

layer_2 = Dense(1024)(layer_1)
layer_2 = Activation('relu')(layer_2)

layer_3 = Dense(1024)(layer_2)
layer_3 = Activation('relu')(layer_3)

layer_4 = Dense(1024)(layer_3)
layer_4 = Activation('relu')(layer_4)
layer_4 = Dropout(0.2)(layer_4, training=False)

layer_5 = Dense(512)(layer_4)
layer_5 = Activation('relu')(layer_5)

layer_6 = Dense(512)(layer_5)
layer_6 = Activation('relu')(layer_6)

layer_7 = Dense(512)(layer_6)
layer_7 = Activation('relu')(layer_7)
layer_7 = Dropout(0.1)(layer_7, training=False)

layer_8 = Dense(256)(layer_7)
layer_8 = Activation('relu')(layer_8)

layer_9 = Dense(256)(layer_8)
layer_9 = Activation('relu')(layer_9)

layer_10 = Dense(256)(layer_9)
layer_10 = Activation('relu')(layer_10)
layer_10 = Dropout(0.3)(layer_10, training=False)

layer_11 = Dense(128)(layer_10)
layer_11 = Activation('relu')(layer_11)

layer_12 = Dense(128)(layer_11)
layer_12 = Activation('relu')(layer_12)

layer_13 = Dense(128)(layer_12)
layer_13 = Activation('relu')(layer_13)
layer_13 = Dropout(0.2)(layer_13, training=False)

layer_14 = Dense(64)(layer_13)
layer_14 = Activation('relu')(layer_14)

layer_15 = Dense(64)(layer_14)
layer_15 = Activation('relu')(layer_15)

layer_16 = Dense(32)(layer_15)
layer_16 = Activation('relu')(layer_16)

out_layer = Dense(1)(layer_16)

model = Model(inputs=in_layer, outputs=out_layer)

weight_files = 'model_elemnet_oqmd_deltae_tf2'
model.load_weights("{}.h5".format(weight_files))

adam = optimizers.Adam(lr=0.0001)
model.compile(loss=tf.keras.losses.mean_absolute_error, optimizer=adam, metrics=['mean_absolute_error'])

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=100, restore_best_weights=True)
# Out:
# 2023-05-14 17:43:04.439682: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2023-05-14 17:43:05.922232: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:3b:00.0 name: Tesla V100-PCIE-16GB computeCapability: 7.0
# coreClock: 1.38GHz coreCount: 80 deviceMemorySize: 15.77GiB deviceMemoryBandwidth: 836.37GiB/s
# 2023-05-14 17:43:05.922487: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:d8:00.0 name: Tesla V100-PCIE-16GB computeCapability: 7.0
# coreClock: 1.38GHz coreCount: 80 deviceMemorySize: 15.77GiB deviceMemoryBandwidth: 836.37GiB/s
# 2023-05-14 17:43:05.922525: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-05-14 17:43:05.959562: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-05-14 17:43:05.959665: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-05-14 17:43:05.964389: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2023-05-14 17:43:05.964761: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2023-05-14 17:43:06.017335: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2023-05-14 17:43:06.021057: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2023-05-14 17:43:06.021326: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-05-14 17:43:06.022477: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0, 1
# 2023-05-14 17:43:06.023044: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-14 17:43:06.221554: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:3b:00.0 name: Tesla V100-PCIE-16GB computeCapability: 7.0
# coreClock: 1.38GHz coreCount: 80 deviceMemorySize: 15.77GiB deviceMemoryBandwidth: 836.37GiB/s
# 2023-05-14 17:43:06.221811: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:d8:00.0 name: Tesla V100-PCIE-16GB computeCapability: 7.0
# coreClock: 1.38GHz coreCount: 80 deviceMemorySize: 15.77GiB deviceMemoryBandwidth: 836.37GiB/s
# 2023-05-14 17:43:06.222496: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0, 1
# 2023-05-14 17:43:06.222558: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-05-14 17:43:07.279660: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-05-14 17:43:07.279706: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1
# 2023-05-14 17:43:07.279715: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N Y
# 2023-05-14 17:43:07.279720: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   Y N
# 2023-05-14 17:43:07.281371: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14635 MB memory) -> physical GPU (device: 0, name: Tesla V100-PCIE-16GB, pci bus id: 0000:3b:00.0, compute capability: 7.0)
# 2023-05-14 17:43:07.282249: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 14635 MB memory) -> physical GPU (device: 1, name: Tesla V100-PCIE-16GB, pci bus id: 0000:d8:00.0, compute capability: 7.0)
# /home/vgf3011/.virtualenvs/tf2_dev/lib64/python3.8/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(

# %%
model.fit(X_train, y_train, verbose=2, validation_data=(X_val, y_val), epochs=3000, batch_size=32, callbacks=[es])
# Out:
# 2023-05-14 17:43:07.989129: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2023-05-14 17:43:07.989757: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2600000000 Hz
# Epoch 1/3000
# 2023-05-14 17:43:08.574508: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-05-14 17:43:09.117249: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 33/33 - 2s - loss: 0.1811 - mean_absolute_error: 0.1811 - val_loss: 0.1563 - val_mean_absolute_error: 0.1563
# Epoch 2/3000
# 33/33 - 0s - loss: 0.1393 - mean_absolute_error: 0.1393 - val_loss: 0.1389 - val_mean_absolute_error: 0.1389
# Epoch 3/3000
# 33/33 - 0s - loss: 0.1163 - mean_absolute_error: 0.1163 - val_loss: 0.1277 - val_mean_absolute_error: 0.1277
# Epoch 4/3000
# 33/33 - 0s - loss: 0.0995 - mean_absolute_error: 0.0995 - val_loss: 0.1228 - val_mean_absolute_error: 0.1228
# Epoch 5/3000
# 33/33 - 0s - loss: 0.0869 - mean_absolute_error: 0.0869 - val_loss: 0.1186 - val_mean_absolute_error: 0.1186
# Epoch 6/3000
# 33/33 - 0s - loss: 0.0784 - mean_absolute_error: 0.0784 - val_loss: 0.1158 - val_mean_absolute_error: 0.1158
# Epoch 7/3000
# 33/33 - 0s - loss: 0.0699 - mean_absolute_error: 0.0699 - val_loss: 0.1121 - val_mean_absolute_error: 0.1121
# Epoch 8/3000
# 33/33 - 0s - loss: 0.0636 - mean_absolute_error: 0.0636 - val_loss: 0.1105 - val_mean_absolute_error: 0.1105
# Epoch 9/3000
# 33/33 - 0s - loss: 0.0578 - mean_absolute_error: 0.0578 - val_loss: 0.1082 - val_mean_absolute_error: 0.1082
# Epoch 10/3000
# 33/33 - 0s - loss: 0.0524 - mean_absolute_error: 0.0524 - val_loss: 0.1070 - val_mean_absolute_error: 0.1070
# Epoch 11/3000
# 33/33 - 0s - loss: 0.0482 - mean_absolute_error: 0.0482 - val_loss: 0.1057 - val_mean_absolute_error: 0.1057
# Epoch 12/3000
# 33/33 - 0s - loss: 0.0471 - mean_absolute_error: 0.0471 - val_loss: 0.1054 - val_mean_absolute_error: 0.1054
# Epoch 13/3000
# 33/33 - 0s - loss: 0.0414 - mean_absolute_error: 0.0414 - val_loss: 0.1053 - val_mean_absolute_error: 0.1053
# Epoch 14/3000
# 33/33 - 0s - loss: 0.0375 - mean_absolute_error: 0.0375 - val_loss: 0.1038 - val_mean_absolute_error: 0.1038
# Epoch 15/3000
# 33/33 - 0s - loss: 0.0352 - mean_absolute_error: 0.0352 - val_loss: 0.1039 - val_mean_absolute_error: 0.1039
# Epoch 16/3000
# 33/33 - 0s - loss: 0.0329 - mean_absolute_error: 0.0329 - val_loss: 0.1038 - val_mean_absolute_error: 0.1038
# Epoch 17/3000
# 33/33 - 0s - loss: 0.0315 - mean_absolute_error: 0.0315 - val_loss: 0.1037 - val_mean_absolute_error: 0.1037
# Epoch 18/3000
# 33/33 - 0s - loss: 0.0287 - mean_absolute_error: 0.0287 - val_loss: 0.1031 - val_mean_absolute_error: 0.1031
# Epoch 19/3000
# 33/33 - 0s - loss: 0.0273 - mean_absolute_error: 0.0273 - val_loss: 0.1026 - val_mean_absolute_error: 0.1026
# Epoch 20/3000
# 33/33 - 0s - loss: 0.0258 - mean_absolute_error: 0.0258 - val_loss: 0.1033 - val_mean_absolute_error: 0.1033
# Epoch 21/3000
# 33/33 - 0s - loss: 0.0248 - mean_absolute_error: 0.0248 - val_loss: 0.1031 - val_mean_absolute_error: 0.1031
# Epoch 22/3000
# 33/33 - 0s - loss: 0.0243 - mean_absolute_error: 0.0243 - val_loss: 0.1031 - val_mean_absolute_error: 0.1031
# Epoch 23/3000
# 33/33 - 0s - loss: 0.0233 - mean_absolute_error: 0.0233 - val_loss: 0.1037 - val_mean_absolute_error: 0.1037
# Epoch 24/3000
# 33/33 - 0s - loss: 0.0222 - mean_absolute_error: 0.0222 - val_loss: 0.1009 - val_mean_absolute_error: 0.1009
# Epoch 25/3000
# 33/33 - 0s - loss: 0.0223 - mean_absolute_error: 0.0223 - val_loss: 0.1024 - val_mean_absolute_error: 0.1024
# Epoch 26/3000
# 33/33 - 0s - loss: 0.0216 - mean_absolute_error: 0.0216 - val_loss: 0.1011 - val_mean_absolute_error: 0.1011
# Epoch 27/3000
# 33/33 - 0s - loss: 0.0196 - mean_absolute_error: 0.0196 - val_loss: 0.1016 - val_mean_absolute_error: 0.1016
# Epoch 28/3000
# 33/33 - 0s - loss: 0.0189 - mean_absolute_error: 0.0189 - val_loss: 0.1012 - val_mean_absolute_error: 0.1012
# Epoch 29/3000
# 33/33 - 0s - loss: 0.0194 - mean_absolute_error: 0.0194 - val_loss: 0.1023 - val_mean_absolute_error: 0.1023
# Epoch 30/3000
# 33/33 - 0s - loss: 0.0204 - mean_absolute_error: 0.0204 - val_loss: 0.1011 - val_mean_absolute_error: 0.1011
# Epoch 31/3000
# 33/33 - 0s - loss: 0.0180 - mean_absolute_error: 0.0180 - val_loss: 0.1008 - val_mean_absolute_error: 0.1008
# Epoch 32/3000
# 33/33 - 0s - loss: 0.0164 - mean_absolute_error: 0.0164 - val_loss: 0.1004 - val_mean_absolute_error: 0.1004
# Epoch 33/3000
# 33/33 - 0s - loss: 0.0170 - mean_absolute_error: 0.0170 - val_loss: 0.1012 - val_mean_absolute_error: 0.1012
# Epoch 34/3000
# 33/33 - 0s - loss: 0.0159 - mean_absolute_error: 0.0159 - val_loss: 0.1003 - val_mean_absolute_error: 0.1003
# Epoch 35/3000
# 33/33 - 0s - loss: 0.0150 - mean_absolute_error: 0.0150 - val_loss: 0.1005 - val_mean_absolute_error: 0.1005
# Epoch 36/3000
# 33/33 - 0s - loss: 0.0143 - mean_absolute_error: 0.0143 - val_loss: 0.1005 - val_mean_absolute_error: 0.1005
# Epoch 37/3000
# 33/33 - 0s - loss: 0.0148 - mean_absolute_error: 0.0148 - val_loss: 0.1004 - val_mean_absolute_error: 0.1004
# Epoch 38/3000
# 33/33 - 0s - loss: 0.0137 - mean_absolute_error: 0.0137 - val_loss: 0.0999 - val_mean_absolute_error: 0.0999
# Epoch 39/3000
# 33/33 - 0s - loss: 0.0131 - mean_absolute_error: 0.0131 - val_loss: 0.1006 - val_mean_absolute_error: 0.1006
# Epoch 40/3000
# 33/33 - 0s - loss: 0.0132 - mean_absolute_error: 0.0132 - val_loss: 0.1007 - val_mean_absolute_error: 0.1007
# Epoch 41/3000
# 33/33 - 0s - loss: 0.0141 - mean_absolute_error: 0.0141 - val_loss: 0.1016 - val_mean_absolute_error: 0.1016
# Epoch 42/3000
# 33/33 - 0s - loss: 0.0135 - mean_absolute_error: 0.0135 - val_loss: 0.1001 - val_mean_absolute_error: 0.1001
# Epoch 43/3000
# 33/33 - 0s - loss: 0.0128 - mean_absolute_error: 0.0128 - val_loss: 0.1005 - val_mean_absolute_error: 0.1005
# Epoch 44/3000
# 33/33 - 0s - loss: 0.0124 - mean_absolute_error: 0.0124 - val_loss: 0.1005 - val_mean_absolute_error: 0.1005
# Epoch 45/3000
# 33/33 - 0s - loss: 0.0132 - mean_absolute_error: 0.0132 - val_loss: 0.1011 - val_mean_absolute_error: 0.1011
# Epoch 46/3000
# 33/33 - 0s - loss: 0.0128 - mean_absolute_error: 0.0128 - val_loss: 0.1001 - val_mean_absolute_error: 0.1001
# Epoch 47/3000
# 33/33 - 0s - loss: 0.0122 - mean_absolute_error: 0.0122 - val_loss: 0.0996 - val_mean_absolute_error: 0.0996
# Epoch 48/3000
# 33/33 - 0s - loss: 0.0121 - mean_absolute_error: 0.0121 - val_loss: 0.0998 - val_mean_absolute_error: 0.0998
# Epoch 49/3000
# 33/33 - 0s - loss: 0.0129 - mean_absolute_error: 0.0129 - val_loss: 0.0989 - val_mean_absolute_error: 0.0989
# Epoch 50/3000
# 33/33 - 0s - loss: 0.0116 - mean_absolute_error: 0.0116 - val_loss: 0.1001 - val_mean_absolute_error: 0.1001
# Epoch 51/3000
# 33/33 - 0s - loss: 0.0111 - mean_absolute_error: 0.0111 - val_loss: 0.0999 - val_mean_absolute_error: 0.0999
# Epoch 52/3000
# 33/33 - 0s - loss: 0.0107 - mean_absolute_error: 0.0107 - val_loss: 0.0996 - val_mean_absolute_error: 0.0996
# Epoch 53/3000
# 33/33 - 0s - loss: 0.0113 - mean_absolute_error: 0.0113 - val_loss: 0.1015 - val_mean_absolute_error: 0.1015
# Epoch 54/3000
# 33/33 - 0s - loss: 0.0105 - mean_absolute_error: 0.0105 - val_loss: 0.1019 - val_mean_absolute_error: 0.1019
# Epoch 55/3000
# 33/33 - 0s - loss: 0.0106 - mean_absolute_error: 0.0106 - val_loss: 0.1001 - val_mean_absolute_error: 0.1001
# Epoch 56/3000
# 33/33 - 0s - loss: 0.0118 - mean_absolute_error: 0.0118 - val_loss: 0.1001 - val_mean_absolute_error: 0.1001
# Epoch 57/3000
# 33/33 - 0s - loss: 0.0104 - mean_absolute_error: 0.0104 - val_loss: 0.1003 - val_mean_absolute_error: 0.1003
# Epoch 58/3000
# 33/33 - 0s - loss: 0.0105 - mean_absolute_error: 0.0105 - val_loss: 0.1010 - val_mean_absolute_error: 0.1010
# Epoch 59/3000
# 33/33 - 0s - loss: 0.0098 - mean_absolute_error: 0.0098 - val_loss: 0.1012 - val_mean_absolute_error: 0.1012
# Epoch 60/3000
# 33/33 - 0s - loss: 0.0104 - mean_absolute_error: 0.0104 - val_loss: 0.1004 - val_mean_absolute_error: 0.1004
# Epoch 61/3000
# 33/33 - 0s - loss: 0.0100 - mean_absolute_error: 0.0100 - val_loss: 0.1020 - val_mean_absolute_error: 0.1020
# Epoch 62/3000
# 33/33 - 0s - loss: 0.0111 - mean_absolute_error: 0.0111 - val_loss: 0.1012 - val_mean_absolute_error: 0.1012
# Epoch 63/3000
# 33/33 - 0s - loss: 0.0100 - mean_absolute_error: 0.0100 - val_loss: 0.1006 - val_mean_absolute_error: 0.1006
# Epoch 64/3000
# 33/33 - 0s - loss: 0.0092 - mean_absolute_error: 0.0092 - val_loss: 0.1009 - val_mean_absolute_error: 0.1009
# Epoch 65/3000
# 33/33 - 0s - loss: 0.0092 - mean_absolute_error: 0.0092 - val_loss: 0.1010 - val_mean_absolute_error: 0.1010
# Epoch 66/3000
# 33/33 - 0s - loss: 0.0094 - mean_absolute_error: 0.0094 - val_loss: 0.1014 - val_mean_absolute_error: 0.1014
# Epoch 67/3000
# 33/33 - 0s - loss: 0.0098 - mean_absolute_error: 0.0098 - val_loss: 0.1019 - val_mean_absolute_error: 0.1019
# Epoch 68/3000
# 33/33 - 0s - loss: 0.0093 - mean_absolute_error: 0.0093 - val_loss: 0.0996 - val_mean_absolute_error: 0.0996
# Epoch 69/3000
# 33/33 - 0s - loss: 0.0090 - mean_absolute_error: 0.0090 - val_loss: 0.1006 - val_mean_absolute_error: 0.1006
# Epoch 70/3000
# 33/33 - 0s - loss: 0.0090 - mean_absolute_error: 0.0090 - val_loss: 0.1009 - val_mean_absolute_error: 0.1009
# Epoch 71/3000
# 33/33 - 0s - loss: 0.0083 - mean_absolute_error: 0.0083 - val_loss: 0.1012 - val_mean_absolute_error: 0.1012
# Epoch 72/3000
# 33/33 - 0s - loss: 0.0105 - mean_absolute_error: 0.0105 - val_loss: 0.1004 - val_mean_absolute_error: 0.1004
# Epoch 73/3000
# 33/33 - 0s - loss: 0.0089 - mean_absolute_error: 0.0089 - val_loss: 0.1006 - val_mean_absolute_error: 0.1006
# Epoch 74/3000
# 33/33 - 0s - loss: 0.0085 - mean_absolute_error: 0.0085 - val_loss: 0.1009 - val_mean_absolute_error: 0.1009
# Epoch 75/3000
# 33/33 - 0s - loss: 0.0085 - mean_absolute_error: 0.0085 - val_loss: 0.0999 - val_mean_absolute_error: 0.0999
# Epoch 76/3000
# 33/33 - 0s - loss: 0.0090 - mean_absolute_error: 0.0090 - val_loss: 0.1005 - val_mean_absolute_error: 0.1005
# Epoch 77/3000
# 33/33 - 0s - loss: 0.0082 - mean_absolute_error: 0.0082 - val_loss: 0.1008 - val_mean_absolute_error: 0.1008
# Epoch 78/3000
# 33/33 - 0s - loss: 0.0093 - mean_absolute_error: 0.0093 - val_loss: 0.1001 - val_mean_absolute_error: 0.1001
# Epoch 79/3000
# 33/33 - 0s - loss: 0.0087 - mean_absolute_error: 0.0087 - val_loss: 0.1012 - val_mean_absolute_error: 0.1012
# Epoch 80/3000
# 33/33 - 0s - loss: 0.0085 - mean_absolute_error: 0.0085 - val_loss: 0.1009 - val_mean_absolute_error: 0.1009
# Epoch 81/3000
# 33/33 - 0s - loss: 0.0090 - mean_absolute_error: 0.0090 - val_loss: 0.1008 - val_mean_absolute_error: 0.1008
# Epoch 82/3000
# 33/33 - 0s - loss: 0.0082 - mean_absolute_error: 0.0082 - val_loss: 0.1008 - val_mean_absolute_error: 0.1008
# Epoch 83/3000
# 33/33 - 0s - loss: 0.0084 - mean_absolute_error: 0.0084 - val_loss: 0.1005 - val_mean_absolute_error: 0.1005
# Epoch 84/3000
# 33/33 - 0s - loss: 0.0079 - mean_absolute_error: 0.0079 - val_loss: 0.1010 - val_mean_absolute_error: 0.1010
# Epoch 85/3000
# 33/33 - 0s - loss: 0.0092 - mean_absolute_error: 0.0092 - val_loss: 0.0994 - val_mean_absolute_error: 0.0994
# Epoch 86/3000
# 33/33 - 0s - loss: 0.0082 - mean_absolute_error: 0.0082 - val_loss: 0.0993 - val_mean_absolute_error: 0.0993
# Epoch 87/3000
# 33/33 - 0s - loss: 0.0088 - mean_absolute_error: 0.0088 - val_loss: 0.1006 - val_mean_absolute_error: 0.1006
# Epoch 88/3000
# 33/33 - 0s - loss: 0.0081 - mean_absolute_error: 0.0081 - val_loss: 0.0996 - val_mean_absolute_error: 0.0996
# Epoch 89/3000
# 33/33 - 0s - loss: 0.0077 - mean_absolute_error: 0.0077 - val_loss: 0.1003 - val_mean_absolute_error: 0.1003
# Epoch 90/3000
# 33/33 - 0s - loss: 0.0080 - mean_absolute_error: 0.0080 - val_loss: 0.0999 - val_mean_absolute_error: 0.0999
# Epoch 91/3000
# 33/33 - 0s - loss: 0.0076 - mean_absolute_error: 0.0076 - val_loss: 0.0997 - val_mean_absolute_error: 0.0997
# Epoch 92/3000
# 33/33 - 0s - loss: 0.0077 - mean_absolute_error: 0.0077 - val_loss: 0.1008 - val_mean_absolute_error: 0.1008
# Epoch 93/3000
# 33/33 - 0s - loss: 0.0077 - mean_absolute_error: 0.0077 - val_loss: 0.1000 - val_mean_absolute_error: 0.1000
# Epoch 94/3000
# 33/33 - 0s - loss: 0.0082 - mean_absolute_error: 0.0082 - val_loss: 0.1002 - val_mean_absolute_error: 0.1002
# Epoch 95/3000
# 33/33 - 0s - loss: 0.0080 - mean_absolute_error: 0.0080 - val_loss: 0.1009 - val_mean_absolute_error: 0.1009
# Epoch 96/3000
# 33/33 - 0s - loss: 0.0078 - mean_absolute_error: 0.0078 - val_loss: 0.1006 - val_mean_absolute_error: 0.1006
# Epoch 97/3000
# 33/33 - 0s - loss: 0.0077 - mean_absolute_error: 0.0077 - val_loss: 0.1002 - val_mean_absolute_error: 0.1002
# Epoch 98/3000
# 33/33 - 0s - loss: 0.0079 - mean_absolute_error: 0.0079 - val_loss: 0.1003 - val_mean_absolute_error: 0.1003
# Epoch 99/3000
# 33/33 - 0s - loss: 0.0073 - mean_absolute_error: 0.0073 - val_loss: 0.1000 - val_mean_absolute_error: 0.1000
# Epoch 100/3000
# 33/33 - 0s - loss: 0.0074 - mean_absolute_error: 0.0074 - val_loss: 0.1005 - val_mean_absolute_error: 0.1005
# Epoch 101/3000
# 33/33 - 0s - loss: 0.0080 - mean_absolute_error: 0.0080 - val_loss: 0.0999 - val_mean_absolute_error: 0.0999
# Epoch 102/3000
# 33/33 - 0s - loss: 0.0073 - mean_absolute_error: 0.0073 - val_loss: 0.0999 - val_mean_absolute_error: 0.0999
# Epoch 103/3000
# 33/33 - 0s - loss: 0.0075 - mean_absolute_error: 0.0075 - val_loss: 0.0999 - val_mean_absolute_error: 0.0999
# Epoch 104/3000
# 33/33 - 0s - loss: 0.0079 - mean_absolute_error: 0.0079 - val_loss: 0.0997 - val_mean_absolute_error: 0.0997
# Epoch 105/3000
# 33/33 - 0s - loss: 0.0077 - mean_absolute_error: 0.0077 - val_loss: 0.1001 - val_mean_absolute_error: 0.1001
# Epoch 106/3000
# 33/33 - 0s - loss: 0.0082 - mean_absolute_error: 0.0082 - val_loss: 0.0998 - val_mean_absolute_error: 0.0998
# Epoch 107/3000
# 33/33 - 0s - loss: 0.0075 - mean_absolute_error: 0.0075 - val_loss: 0.1001 - val_mean_absolute_error: 0.1001
# Epoch 108/3000
# 33/33 - 0s - loss: 0.0073 - mean_absolute_error: 0.0073 - val_loss: 0.0999 - val_mean_absolute_error: 0.0999
# Epoch 109/3000
# 33/33 - 0s - loss: 0.0080 - mean_absolute_error: 0.0080 - val_loss: 0.1002 - val_mean_absolute_error: 0.1002
# Epoch 110/3000
# 33/33 - 0s - loss: 0.0075 - mean_absolute_error: 0.0075 - val_loss: 0.0997 - val_mean_absolute_error: 0.0997
# Epoch 111/3000
# 33/33 - 0s - loss: 0.0075 - mean_absolute_error: 0.0075 - val_loss: 0.1006 - val_mean_absolute_error: 0.1006
# Epoch 112/3000
# 33/33 - 0s - loss: 0.0090 - mean_absolute_error: 0.0090 - val_loss: 0.0995 - val_mean_absolute_error: 0.0995
# Epoch 113/3000
# 33/33 - 0s - loss: 0.0075 - mean_absolute_error: 0.0075 - val_loss: 0.1000 - val_mean_absolute_error: 0.1000
# Epoch 114/3000
# 33/33 - 0s - loss: 0.0077 - mean_absolute_error: 0.0077 - val_loss: 0.0992 - val_mean_absolute_error: 0.0992
# Epoch 115/3000
# 33/33 - 0s - loss: 0.0074 - mean_absolute_error: 0.0074 - val_loss: 0.1000 - val_mean_absolute_error: 0.1000
# Epoch 116/3000
# 33/33 - 0s - loss: 0.0077 - mean_absolute_error: 0.0077 - val_loss: 0.0999 - val_mean_absolute_error: 0.0999
# Epoch 117/3000
# 33/33 - 0s - loss: 0.0078 - mean_absolute_error: 0.0078 - val_loss: 0.0997 - val_mean_absolute_error: 0.0997
# Epoch 118/3000
# 33/33 - 0s - loss: 0.0079 - mean_absolute_error: 0.0079 - val_loss: 0.0995 - val_mean_absolute_error: 0.0995
# Epoch 119/3000
# 33/33 - 0s - loss: 0.0077 - mean_absolute_error: 0.0077 - val_loss: 0.0995 - val_mean_absolute_error: 0.0995
# Epoch 120/3000
# 33/33 - 0s - loss: 0.0074 - mean_absolute_error: 0.0074 - val_loss: 0.0991 - val_mean_absolute_error: 0.0991
# Epoch 121/3000
# 33/33 - 0s - loss: 0.0081 - mean_absolute_error: 0.0081 - val_loss: 0.0996 - val_mean_absolute_error: 0.0996
# Epoch 122/3000
# 33/33 - 0s - loss: 0.0087 - mean_absolute_error: 0.0087 - val_loss: 0.0995 - val_mean_absolute_error: 0.0995
# Epoch 123/3000
# 33/33 - 0s - loss: 0.0085 - mean_absolute_error: 0.0085 - val_loss: 0.0998 - val_mean_absolute_error: 0.0998
# Epoch 124/3000
# 33/33 - 0s - loss: 0.0075 - mean_absolute_error: 0.0075 - val_loss: 0.1001 - val_mean_absolute_error: 0.1001
# Epoch 125/3000
# 33/33 - 0s - loss: 0.0071 - mean_absolute_error: 0.0071 - val_loss: 0.1004 - val_mean_absolute_error: 0.1004
# Epoch 126/3000
# 33/33 - 0s - loss: 0.0082 - mean_absolute_error: 0.0082 - val_loss: 0.1005 - val_mean_absolute_error: 0.1005
# Epoch 127/3000
# 33/33 - 0s - loss: 0.0076 - mean_absolute_error: 0.0076 - val_loss: 0.0994 - val_mean_absolute_error: 0.0994
# Epoch 128/3000
# 33/33 - 0s - loss: 0.0071 - mean_absolute_error: 0.0071 - val_loss: 0.1007 - val_mean_absolute_error: 0.1007
# Epoch 129/3000
# 33/33 - 0s - loss: 0.0073 - mean_absolute_error: 0.0073 - val_loss: 0.0992 - val_mean_absolute_error: 0.0992
# Epoch 130/3000
# 33/33 - 0s - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.1000 - val_mean_absolute_error: 0.1000
# Epoch 131/3000
# 33/33 - 0s - loss: 0.0073 - mean_absolute_error: 0.0073 - val_loss: 0.0998 - val_mean_absolute_error: 0.0998
# Epoch 132/3000
# 33/33 - 0s - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.0983 - val_mean_absolute_error: 0.0983
# Epoch 133/3000
# 33/33 - 0s - loss: 0.0079 - mean_absolute_error: 0.0079 - val_loss: 0.0988 - val_mean_absolute_error: 0.0988
# Epoch 134/3000
# 33/33 - 0s - loss: 0.0071 - mean_absolute_error: 0.0071 - val_loss: 0.0991 - val_mean_absolute_error: 0.0991
# Epoch 135/3000
# 33/33 - 0s - loss: 0.0067 - mean_absolute_error: 0.0067 - val_loss: 0.0994 - val_mean_absolute_error: 0.0994
# Epoch 136/3000
# 33/33 - 0s - loss: 0.0077 - mean_absolute_error: 0.0077 - val_loss: 0.1003 - val_mean_absolute_error: 0.1003
# Epoch 137/3000
# 33/33 - 0s - loss: 0.0075 - mean_absolute_error: 0.0075 - val_loss: 0.0997 - val_mean_absolute_error: 0.0997
# Epoch 138/3000
# 33/33 - 0s - loss: 0.0071 - mean_absolute_error: 0.0071 - val_loss: 0.0988 - val_mean_absolute_error: 0.0988
# Epoch 139/3000
# 33/33 - 0s - loss: 0.0074 - mean_absolute_error: 0.0074 - val_loss: 0.0984 - val_mean_absolute_error: 0.0984
# Epoch 140/3000
# 33/33 - 0s - loss: 0.0075 - mean_absolute_error: 0.0075 - val_loss: 0.0991 - val_mean_absolute_error: 0.0991
# Epoch 141/3000
# 33/33 - 0s - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.0979 - val_mean_absolute_error: 0.0979
# Epoch 142/3000
# 33/33 - 0s - loss: 0.0074 - mean_absolute_error: 0.0074 - val_loss: 0.0987 - val_mean_absolute_error: 0.0987
# Epoch 143/3000
# 33/33 - 0s - loss: 0.0081 - mean_absolute_error: 0.0081 - val_loss: 0.0988 - val_mean_absolute_error: 0.0988
# Epoch 144/3000
# 33/33 - 0s - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.0993 - val_mean_absolute_error: 0.0993
# Epoch 145/3000
# 33/33 - 0s - loss: 0.0069 - mean_absolute_error: 0.0069 - val_loss: 0.0984 - val_mean_absolute_error: 0.0984
# Epoch 146/3000
# 33/33 - 0s - loss: 0.0073 - mean_absolute_error: 0.0073 - val_loss: 0.0985 - val_mean_absolute_error: 0.0985
# Epoch 147/3000
# 33/33 - 0s - loss: 0.0069 - mean_absolute_error: 0.0069 - val_loss: 0.0988 - val_mean_absolute_error: 0.0988
# Epoch 148/3000
# 33/33 - 0s - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.0992 - val_mean_absolute_error: 0.0992
# Epoch 149/3000
# 33/33 - 0s - loss: 0.0069 - mean_absolute_error: 0.0069 - val_loss: 0.0991 - val_mean_absolute_error: 0.0991
# Epoch 150/3000
# 33/33 - 0s - loss: 0.0065 - mean_absolute_error: 0.0065 - val_loss: 0.0986 - val_mean_absolute_error: 0.0986
# Epoch 151/3000
# 33/33 - 0s - loss: 0.0067 - mean_absolute_error: 0.0067 - val_loss: 0.0991 - val_mean_absolute_error: 0.0991
# Epoch 152/3000
# 33/33 - 0s - loss: 0.0068 - mean_absolute_error: 0.0068 - val_loss: 0.0986 - val_mean_absolute_error: 0.0986
# Epoch 153/3000
# 33/33 - 0s - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.0987 - val_mean_absolute_error: 0.0987
# Epoch 154/3000
# 33/33 - 0s - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.0983 - val_mean_absolute_error: 0.0983
# Epoch 155/3000
# 33/33 - 0s - loss: 0.0073 - mean_absolute_error: 0.0073 - val_loss: 0.0991 - val_mean_absolute_error: 0.0991
# Epoch 156/3000
# 33/33 - 0s - loss: 0.0073 - mean_absolute_error: 0.0073 - val_loss: 0.0991 - val_mean_absolute_error: 0.0991
# Epoch 157/3000
# 33/33 - 0s - loss: 0.0079 - mean_absolute_error: 0.0079 - val_loss: 0.0992 - val_mean_absolute_error: 0.0992
# Epoch 158/3000
# 33/33 - 0s - loss: 0.0074 - mean_absolute_error: 0.0074 - val_loss: 0.0993 - val_mean_absolute_error: 0.0993
# Epoch 159/3000
# 33/33 - 0s - loss: 0.0077 - mean_absolute_error: 0.0077 - val_loss: 0.0992 - val_mean_absolute_error: 0.0992
# Epoch 160/3000
# 33/33 - 0s - loss: 0.0080 - mean_absolute_error: 0.0080 - val_loss: 0.0984 - val_mean_absolute_error: 0.0984
# Epoch 161/3000
# 33/33 - 0s - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.0978 - val_mean_absolute_error: 0.0978
# Epoch 162/3000
# 33/33 - 0s - loss: 0.0069 - mean_absolute_error: 0.0069 - val_loss: 0.0984 - val_mean_absolute_error: 0.0984
# Epoch 163/3000
# 33/33 - 0s - loss: 0.0065 - mean_absolute_error: 0.0065 - val_loss: 0.0982 - val_mean_absolute_error: 0.0982
# Epoch 164/3000
# 33/33 - 0s - loss: 0.0074 - mean_absolute_error: 0.0074 - val_loss: 0.0979 - val_mean_absolute_error: 0.0979
# Epoch 165/3000
# 33/33 - 0s - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.0984 - val_mean_absolute_error: 0.0984
# Epoch 166/3000
# 33/33 - 0s - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.0976 - val_mean_absolute_error: 0.0976
# Epoch 167/3000
# 33/33 - 0s - loss: 0.0068 - mean_absolute_error: 0.0068 - val_loss: 0.0983 - val_mean_absolute_error: 0.0983
# Epoch 168/3000
# 33/33 - 0s - loss: 0.0061 - mean_absolute_error: 0.0061 - val_loss: 0.0984 - val_mean_absolute_error: 0.0984
# Epoch 169/3000
# 33/33 - 0s - loss: 0.0067 - mean_absolute_error: 0.0067 - val_loss: 0.0981 - val_mean_absolute_error: 0.0981
# Epoch 170/3000
# 33/33 - 0s - loss: 0.0078 - mean_absolute_error: 0.0078 - val_loss: 0.0976 - val_mean_absolute_error: 0.0976
# Epoch 171/3000
# 33/33 - 0s - loss: 0.0074 - mean_absolute_error: 0.0074 - val_loss: 0.0982 - val_mean_absolute_error: 0.0982
# Epoch 172/3000
# 33/33 - 0s - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.0985 - val_mean_absolute_error: 0.0985
# Epoch 173/3000
# 33/33 - 0s - loss: 0.0066 - mean_absolute_error: 0.0066 - val_loss: 0.0985 - val_mean_absolute_error: 0.0985
# Epoch 174/3000
# 33/33 - 0s - loss: 0.0065 - mean_absolute_error: 0.0065 - val_loss: 0.0985 - val_mean_absolute_error: 0.0985
# Epoch 175/3000
# 33/33 - 0s - loss: 0.0071 - mean_absolute_error: 0.0071 - val_loss: 0.0978 - val_mean_absolute_error: 0.0978
# Epoch 176/3000
# 33/33 - 0s - loss: 0.0075 - mean_absolute_error: 0.0075 - val_loss: 0.0972 - val_mean_absolute_error: 0.0972
# Epoch 177/3000
# 33/33 - 0s - loss: 0.0074 - mean_absolute_error: 0.0074 - val_loss: 0.0991 - val_mean_absolute_error: 0.0991
# Epoch 178/3000
# 33/33 - 0s - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.0980 - val_mean_absolute_error: 0.0980
# Epoch 179/3000
# 33/33 - 0s - loss: 0.0089 - mean_absolute_error: 0.0089 - val_loss: 0.0976 - val_mean_absolute_error: 0.0976
# Epoch 180/3000
# 33/33 - 0s - loss: 0.0075 - mean_absolute_error: 0.0075 - val_loss: 0.0975 - val_mean_absolute_error: 0.0975
# Epoch 181/3000
# 33/33 - 0s - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.0982 - val_mean_absolute_error: 0.0982
# Epoch 182/3000
# 33/33 - 0s - loss: 0.0065 - mean_absolute_error: 0.0065 - val_loss: 0.0973 - val_mean_absolute_error: 0.0973
# Epoch 183/3000
# 33/33 - 0s - loss: 0.0074 - mean_absolute_error: 0.0074 - val_loss: 0.0977 - val_mean_absolute_error: 0.0977
# Epoch 184/3000
# 33/33 - 0s - loss: 0.0063 - mean_absolute_error: 0.0063 - val_loss: 0.0977 - val_mean_absolute_error: 0.0977
# Epoch 185/3000
# 33/33 - 0s - loss: 0.0062 - mean_absolute_error: 0.0062 - val_loss: 0.0971 - val_mean_absolute_error: 0.0971
# Epoch 186/3000
# 33/33 - 0s - loss: 0.0064 - mean_absolute_error: 0.0064 - val_loss: 0.0975 - val_mean_absolute_error: 0.0975
# Epoch 187/3000
# 33/33 - 0s - loss: 0.0071 - mean_absolute_error: 0.0071 - val_loss: 0.0982 - val_mean_absolute_error: 0.0982
# Epoch 188/3000
# 33/33 - 0s - loss: 0.0066 - mean_absolute_error: 0.0066 - val_loss: 0.0976 - val_mean_absolute_error: 0.0976
# Epoch 189/3000
# 33/33 - 0s - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.0970 - val_mean_absolute_error: 0.0970
# Epoch 190/3000
# 33/33 - 0s - loss: 0.0067 - mean_absolute_error: 0.0067 - val_loss: 0.0973 - val_mean_absolute_error: 0.0973
# Epoch 191/3000
# 33/33 - 0s - loss: 0.0064 - mean_absolute_error: 0.0064 - val_loss: 0.0968 - val_mean_absolute_error: 0.0968
# Epoch 192/3000
# 33/33 - 0s - loss: 0.0078 - mean_absolute_error: 0.0078 - val_loss: 0.0978 - val_mean_absolute_error: 0.0978
# Epoch 193/3000
# 33/33 - 0s - loss: 0.0077 - mean_absolute_error: 0.0077 - val_loss: 0.0976 - val_mean_absolute_error: 0.0976
# Epoch 194/3000
# 33/33 - 0s - loss: 0.0077 - mean_absolute_error: 0.0077 - val_loss: 0.0978 - val_mean_absolute_error: 0.0978
# Epoch 195/3000
# 33/33 - 0s - loss: 0.0065 - mean_absolute_error: 0.0065 - val_loss: 0.0979 - val_mean_absolute_error: 0.0979
# Epoch 196/3000
# 33/33 - 0s - loss: 0.0064 - mean_absolute_error: 0.0064 - val_loss: 0.0969 - val_mean_absolute_error: 0.0969
# Epoch 197/3000
# 33/33 - 0s - loss: 0.0062 - mean_absolute_error: 0.0062 - val_loss: 0.0967 - val_mean_absolute_error: 0.0967
# Epoch 198/3000
# 33/33 - 0s - loss: 0.0073 - mean_absolute_error: 0.0073 - val_loss: 0.0967 - val_mean_absolute_error: 0.0967
# Epoch 199/3000
# 33/33 - 0s - loss: 0.0068 - mean_absolute_error: 0.0068 - val_loss: 0.0967 - val_mean_absolute_error: 0.0967
# Epoch 200/3000
# 33/33 - 0s - loss: 0.0081 - mean_absolute_error: 0.0081 - val_loss: 0.0969 - val_mean_absolute_error: 0.0969
# Epoch 201/3000
# 33/33 - 0s - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.0978 - val_mean_absolute_error: 0.0978
# Epoch 202/3000
# 33/33 - 0s - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.0965 - val_mean_absolute_error: 0.0965
# Epoch 203/3000
# 33/33 - 0s - loss: 0.0065 - mean_absolute_error: 0.0065 - val_loss: 0.0969 - val_mean_absolute_error: 0.0969
# Epoch 204/3000
# 33/33 - 0s - loss: 0.0064 - mean_absolute_error: 0.0064 - val_loss: 0.0972 - val_mean_absolute_error: 0.0972
# Epoch 205/3000
# 33/33 - 0s - loss: 0.0067 - mean_absolute_error: 0.0067 - val_loss: 0.0969 - val_mean_absolute_error: 0.0969
# Epoch 206/3000
# 33/33 - 0s - loss: 0.0065 - mean_absolute_error: 0.0065 - val_loss: 0.0966 - val_mean_absolute_error: 0.0966
# Epoch 207/3000
# 33/33 - 0s - loss: 0.0080 - mean_absolute_error: 0.0080 - val_loss: 0.0983 - val_mean_absolute_error: 0.0983
# Epoch 208/3000
# 33/33 - 0s - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.0973 - val_mean_absolute_error: 0.0973
# Epoch 209/3000
# 33/33 - 0s - loss: 0.0077 - mean_absolute_error: 0.0077 - val_loss: 0.0974 - val_mean_absolute_error: 0.0974
# Epoch 210/3000
# 33/33 - 0s - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.0964 - val_mean_absolute_error: 0.0964
# Epoch 211/3000
# 33/33 - 0s - loss: 0.0068 - mean_absolute_error: 0.0068 - val_loss: 0.0982 - val_mean_absolute_error: 0.0982
# Epoch 212/3000
# 33/33 - 0s - loss: 0.0062 - mean_absolute_error: 0.0062 - val_loss: 0.0967 - val_mean_absolute_error: 0.0967
# Epoch 213/3000
# 33/33 - 0s - loss: 0.0068 - mean_absolute_error: 0.0068 - val_loss: 0.0975 - val_mean_absolute_error: 0.0975
# Epoch 214/3000
# 33/33 - 0s - loss: 0.0068 - mean_absolute_error: 0.0068 - val_loss: 0.0974 - val_mean_absolute_error: 0.0974
# Epoch 215/3000
# 33/33 - 0s - loss: 0.0067 - mean_absolute_error: 0.0067 - val_loss: 0.0967 - val_mean_absolute_error: 0.0967
# Epoch 216/3000
# 33/33 - 0s - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.0973 - val_mean_absolute_error: 0.0973
# Epoch 217/3000
# 33/33 - 0s - loss: 0.0062 - mean_absolute_error: 0.0062 - val_loss: 0.0975 - val_mean_absolute_error: 0.0975
# Epoch 218/3000
# 33/33 - 0s - loss: 0.0076 - mean_absolute_error: 0.0076 - val_loss: 0.0965 - val_mean_absolute_error: 0.0965
# Epoch 219/3000
# 33/33 - 0s - loss: 0.0080 - mean_absolute_error: 0.0080 - val_loss: 0.0969 - val_mean_absolute_error: 0.0969
# Epoch 220/3000
# 33/33 - 0s - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.0967 - val_mean_absolute_error: 0.0967
# Epoch 221/3000
# 33/33 - 0s - loss: 0.0065 - mean_absolute_error: 0.0065 - val_loss: 0.0974 - val_mean_absolute_error: 0.0974
# Epoch 222/3000
# 33/33 - 0s - loss: 0.0058 - mean_absolute_error: 0.0058 - val_loss: 0.0965 - val_mean_absolute_error: 0.0965
# Epoch 223/3000
# 33/33 - 0s - loss: 0.0063 - mean_absolute_error: 0.0063 - val_loss: 0.0973 - val_mean_absolute_error: 0.0973
# Epoch 224/3000
# 33/33 - 0s - loss: 0.0061 - mean_absolute_error: 0.0061 - val_loss: 0.0964 - val_mean_absolute_error: 0.0964
# Epoch 225/3000
# 33/33 - 0s - loss: 0.0065 - mean_absolute_error: 0.0065 - val_loss: 0.0965 - val_mean_absolute_error: 0.0965
# Epoch 226/3000
# 33/33 - 0s - loss: 0.0066 - mean_absolute_error: 0.0066 - val_loss: 0.0959 - val_mean_absolute_error: 0.0959
# Epoch 227/3000
# 33/33 - 0s - loss: 0.0068 - mean_absolute_error: 0.0068 - val_loss: 0.0969 - val_mean_absolute_error: 0.0969
# Epoch 228/3000
# 33/33 - 0s - loss: 0.0077 - mean_absolute_error: 0.0077 - val_loss: 0.0965 - val_mean_absolute_error: 0.0965
# Epoch 229/3000
# 33/33 - 0s - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.0977 - val_mean_absolute_error: 0.0977
# Epoch 230/3000
# 33/33 - 0s - loss: 0.0064 - mean_absolute_error: 0.0064 - val_loss: 0.0965 - val_mean_absolute_error: 0.0965
# Epoch 231/3000
# 33/33 - 0s - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.0971 - val_mean_absolute_error: 0.0971
# Epoch 232/3000
# 33/33 - 0s - loss: 0.0060 - mean_absolute_error: 0.0060 - val_loss: 0.0970 - val_mean_absolute_error: 0.0970
# Epoch 233/3000
# 33/33 - 0s - loss: 0.0073 - mean_absolute_error: 0.0073 - val_loss: 0.0962 - val_mean_absolute_error: 0.0962
# Epoch 234/3000
# 33/33 - 0s - loss: 0.0076 - mean_absolute_error: 0.0076 - val_loss: 0.0971 - val_mean_absolute_error: 0.0971
# Epoch 235/3000
# 33/33 - 0s - loss: 0.0075 - mean_absolute_error: 0.0075 - val_loss: 0.0969 - val_mean_absolute_error: 0.0969
# Epoch 236/3000
# 33/33 - 0s - loss: 0.0073 - mean_absolute_error: 0.0073 - val_loss: 0.0960 - val_mean_absolute_error: 0.0960
# Epoch 237/3000
# 33/33 - 0s - loss: 0.0073 - mean_absolute_error: 0.0073 - val_loss: 0.0967 - val_mean_absolute_error: 0.0967
# Epoch 238/3000
# 33/33 - 0s - loss: 0.0066 - mean_absolute_error: 0.0066 - val_loss: 0.0961 - val_mean_absolute_error: 0.0961
# Epoch 239/3000
# 33/33 - 0s - loss: 0.0063 - mean_absolute_error: 0.0063 - val_loss: 0.0962 - val_mean_absolute_error: 0.0962
# Epoch 240/3000
# 33/33 - 0s - loss: 0.0061 - mean_absolute_error: 0.0061 - val_loss: 0.0964 - val_mean_absolute_error: 0.0964
# Epoch 241/3000
# 33/33 - 0s - loss: 0.0062 - mean_absolute_error: 0.0062 - val_loss: 0.0962 - val_mean_absolute_error: 0.0962
# Epoch 242/3000
# 33/33 - 0s - loss: 0.0074 - mean_absolute_error: 0.0074 - val_loss: 0.0959 - val_mean_absolute_error: 0.0959
# Epoch 243/3000
# 33/33 - 0s - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.0965 - val_mean_absolute_error: 0.0965
# Epoch 244/3000
# 33/33 - 0s - loss: 0.0062 - mean_absolute_error: 0.0062 - val_loss: 0.0958 - val_mean_absolute_error: 0.0958
# Epoch 245/3000
# 33/33 - 0s - loss: 0.0064 - mean_absolute_error: 0.0064 - val_loss: 0.0961 - val_mean_absolute_error: 0.0961
# Epoch 246/3000
# 33/33 - 0s - loss: 0.0071 - mean_absolute_error: 0.0071 - val_loss: 0.0954 - val_mean_absolute_error: 0.0954
# Epoch 247/3000
# 33/33 - 0s - loss: 0.0073 - mean_absolute_error: 0.0073 - val_loss: 0.0963 - val_mean_absolute_error: 0.0963
# Epoch 248/3000
# 33/33 - 0s - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.0966 - val_mean_absolute_error: 0.0966
# Epoch 249/3000
# 33/33 - 0s - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.0954 - val_mean_absolute_error: 0.0954
# Epoch 250/3000
# 33/33 - 0s - loss: 0.0074 - mean_absolute_error: 0.0074 - val_loss: 0.0973 - val_mean_absolute_error: 0.0973
# Epoch 251/3000
# 33/33 - 0s - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.0958 - val_mean_absolute_error: 0.0958
# Epoch 252/3000
# 33/33 - 0s - loss: 0.0062 - mean_absolute_error: 0.0062 - val_loss: 0.0966 - val_mean_absolute_error: 0.0966
# Epoch 253/3000
# 33/33 - 0s - loss: 0.0063 - mean_absolute_error: 0.0063 - val_loss: 0.0957 - val_mean_absolute_error: 0.0957
# Epoch 254/3000
# 33/33 - 0s - loss: 0.0059 - mean_absolute_error: 0.0059 - val_loss: 0.0958 - val_mean_absolute_error: 0.0958
# Epoch 255/3000
# 33/33 - 0s - loss: 0.0065 - mean_absolute_error: 0.0065 - val_loss: 0.0956 - val_mean_absolute_error: 0.0956
# Epoch 256/3000
# 33/33 - 0s - loss: 0.0068 - mean_absolute_error: 0.0068 - val_loss: 0.0961 - val_mean_absolute_error: 0.0961
# Epoch 257/3000
# 33/33 - 0s - loss: 0.0085 - mean_absolute_error: 0.0085 - val_loss: 0.0963 - val_mean_absolute_error: 0.0963
# Epoch 258/3000
# 33/33 - 0s - loss: 0.0064 - mean_absolute_error: 0.0064 - val_loss: 0.0958 - val_mean_absolute_error: 0.0958
# Epoch 259/3000
# 33/33 - 0s - loss: 0.0071 - mean_absolute_error: 0.0071 - val_loss: 0.0958 - val_mean_absolute_error: 0.0958
# Epoch 260/3000
# 33/33 - 0s - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.0953 - val_mean_absolute_error: 0.0953
# Epoch 261/3000
# 33/33 - 0s - loss: 0.0066 - mean_absolute_error: 0.0066 - val_loss: 0.0978 - val_mean_absolute_error: 0.0978
# Epoch 262/3000
# 33/33 - 0s - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.0962 - val_mean_absolute_error: 0.0962
# Epoch 263/3000
# 33/33 - 0s - loss: 0.0069 - mean_absolute_error: 0.0069 - val_loss: 0.0957 - val_mean_absolute_error: 0.0957
# Epoch 264/3000
# 33/33 - 0s - loss: 0.0068 - mean_absolute_error: 0.0068 - val_loss: 0.0959 - val_mean_absolute_error: 0.0959
# Epoch 265/3000
# 33/33 - 0s - loss: 0.0068 - mean_absolute_error: 0.0068 - val_loss: 0.0962 - val_mean_absolute_error: 0.0962
# Epoch 266/3000
# 33/33 - 0s - loss: 0.0061 - mean_absolute_error: 0.0061 - val_loss: 0.0958 - val_mean_absolute_error: 0.0958
# Epoch 267/3000
# 33/33 - 0s - loss: 0.0063 - mean_absolute_error: 0.0063 - val_loss: 0.0960 - val_mean_absolute_error: 0.0960
# Epoch 268/3000
# 33/33 - 0s - loss: 0.0062 - mean_absolute_error: 0.0062 - val_loss: 0.0957 - val_mean_absolute_error: 0.0957
# Epoch 269/3000
# 33/33 - 0s - loss: 0.0066 - mean_absolute_error: 0.0066 - val_loss: 0.0957 - val_mean_absolute_error: 0.0957
# Epoch 270/3000
# 33/33 - 0s - loss: 0.0071 - mean_absolute_error: 0.0071 - val_loss: 0.0965 - val_mean_absolute_error: 0.0965
# Epoch 271/3000
# 33/33 - 0s - loss: 0.0069 - mean_absolute_error: 0.0069 - val_loss: 0.0956 - val_mean_absolute_error: 0.0956
# Epoch 272/3000
# 33/33 - 0s - loss: 0.0064 - mean_absolute_error: 0.0064 - val_loss: 0.0953 - val_mean_absolute_error: 0.0953
# Epoch 273/3000
# 33/33 - 0s - loss: 0.0063 - mean_absolute_error: 0.0063 - val_loss: 0.0951 - val_mean_absolute_error: 0.0951
# Epoch 274/3000
# 33/33 - 0s - loss: 0.0059 - mean_absolute_error: 0.0059 - val_loss: 0.0958 - val_mean_absolute_error: 0.0958
# Epoch 275/3000
# 33/33 - 0s - loss: 0.0064 - mean_absolute_error: 0.0064 - val_loss: 0.0954 - val_mean_absolute_error: 0.0954
# Epoch 276/3000
# 33/33 - 0s - loss: 0.0064 - mean_absolute_error: 0.0064 - val_loss: 0.0972 - val_mean_absolute_error: 0.0972
# Epoch 277/3000
# 33/33 - 0s - loss: 0.0069 - mean_absolute_error: 0.0069 - val_loss: 0.0959 - val_mean_absolute_error: 0.0959
# Epoch 278/3000
# 33/33 - 0s - loss: 0.0063 - mean_absolute_error: 0.0063 - val_loss: 0.0960 - val_mean_absolute_error: 0.0960
# Epoch 279/3000
# 33/33 - 0s - loss: 0.0061 - mean_absolute_error: 0.0061 - val_loss: 0.0948 - val_mean_absolute_error: 0.0948
# Epoch 280/3000
# 33/33 - 0s - loss: 0.0061 - mean_absolute_error: 0.0061 - val_loss: 0.0950 - val_mean_absolute_error: 0.0950
# Epoch 281/3000
# 33/33 - 0s - loss: 0.0062 - mean_absolute_error: 0.0062 - val_loss: 0.0957 - val_mean_absolute_error: 0.0957
# Epoch 282/3000
# 33/33 - 0s - loss: 0.0063 - mean_absolute_error: 0.0063 - val_loss: 0.0955 - val_mean_absolute_error: 0.0955
# Epoch 283/3000
# 33/33 - 0s - loss: 0.0063 - mean_absolute_error: 0.0063 - val_loss: 0.0956 - val_mean_absolute_error: 0.0956
# Epoch 284/3000
# 33/33 - 0s - loss: 0.0066 - mean_absolute_error: 0.0066 - val_loss: 0.0954 - val_mean_absolute_error: 0.0954
# Epoch 285/3000
# 33/33 - 0s - loss: 0.0061 - mean_absolute_error: 0.0061 - val_loss: 0.0959 - val_mean_absolute_error: 0.0959
# Epoch 286/3000
# 33/33 - 0s - loss: 0.0060 - mean_absolute_error: 0.0060 - val_loss: 0.0955 - val_mean_absolute_error: 0.0955
# Epoch 287/3000
# 33/33 - 0s - loss: 0.0063 - mean_absolute_error: 0.0063 - val_loss: 0.0952 - val_mean_absolute_error: 0.0952
# Epoch 288/3000
# 33/33 - 0s - loss: 0.0065 - mean_absolute_error: 0.0065 - val_loss: 0.0960 - val_mean_absolute_error: 0.0960
# Epoch 289/3000
# 33/33 - 0s - loss: 0.0067 - mean_absolute_error: 0.0067 - val_loss: 0.0955 - val_mean_absolute_error: 0.0955
# Epoch 290/3000
# 33/33 - 0s - loss: 0.0066 - mean_absolute_error: 0.0066 - val_loss: 0.0954 - val_mean_absolute_error: 0.0954
# Epoch 291/3000
# 33/33 - 0s - loss: 0.0069 - mean_absolute_error: 0.0069 - val_loss: 0.0964 - val_mean_absolute_error: 0.0964
# Epoch 292/3000
# 33/33 - 0s - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.0949 - val_mean_absolute_error: 0.0949
# Epoch 293/3000
# 33/33 - 0s - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.0955 - val_mean_absolute_error: 0.0955
# Epoch 294/3000
# 33/33 - 0s - loss: 0.0069 - mean_absolute_error: 0.0069 - val_loss: 0.0953 - val_mean_absolute_error: 0.0953
# Epoch 295/3000
# 33/33 - 0s - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.0963 - val_mean_absolute_error: 0.0963
# Epoch 296/3000
# 33/33 - 0s - loss: 0.0065 - mean_absolute_error: 0.0065 - val_loss: 0.0957 - val_mean_absolute_error: 0.0957
# Epoch 297/3000
# 33/33 - 0s - loss: 0.0059 - mean_absolute_error: 0.0059 - val_loss: 0.0952 - val_mean_absolute_error: 0.0952
# Epoch 298/3000
# 33/33 - 0s - loss: 0.0062 - mean_absolute_error: 0.0062 - val_loss: 0.0951 - val_mean_absolute_error: 0.0951
# Epoch 299/3000
# 33/33 - 0s - loss: 0.0061 - mean_absolute_error: 0.0061 - val_loss: 0.0947 - val_mean_absolute_error: 0.0947
# Epoch 300/3000
# 33/33 - 0s - loss: 0.0062 - mean_absolute_error: 0.0062 - val_loss: 0.0958 - val_mean_absolute_error: 0.0958
# Epoch 301/3000
# 33/33 - 0s - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.0955 - val_mean_absolute_error: 0.0955
# Epoch 302/3000
# 33/33 - 0s - loss: 0.0071 - mean_absolute_error: 0.0071 - val_loss: 0.0954 - val_mean_absolute_error: 0.0954
# Epoch 303/3000
# 33/33 - 0s - loss: 0.0065 - mean_absolute_error: 0.0065 - val_loss: 0.0954 - val_mean_absolute_error: 0.0954
# Epoch 304/3000
# 33/33 - 0s - loss: 0.0069 - mean_absolute_error: 0.0069 - val_loss: 0.0947 - val_mean_absolute_error: 0.0947
# Epoch 305/3000
# 33/33 - 0s - loss: 0.0064 - mean_absolute_error: 0.0064 - val_loss: 0.0950 - val_mean_absolute_error: 0.0950
# Epoch 306/3000
# 33/33 - 0s - loss: 0.0061 - mean_absolute_error: 0.0061 - val_loss: 0.0948 - val_mean_absolute_error: 0.0948
# Epoch 307/3000
# 33/33 - 0s - loss: 0.0060 - mean_absolute_error: 0.0060 - val_loss: 0.0946 - val_mean_absolute_error: 0.0946
# Epoch 308/3000
# 33/33 - 0s - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.0953 - val_mean_absolute_error: 0.0953
# Epoch 309/3000
# 33/33 - 0s - loss: 0.0061 - mean_absolute_error: 0.0061 - val_loss: 0.0945 - val_mean_absolute_error: 0.0945
# Epoch 310/3000
# 33/33 - 0s - loss: 0.0068 - mean_absolute_error: 0.0068 - val_loss: 0.0943 - val_mean_absolute_error: 0.0943
# Epoch 311/3000
# 33/33 - 0s - loss: 0.0064 - mean_absolute_error: 0.0064 - val_loss: 0.0945 - val_mean_absolute_error: 0.0945
# Epoch 312/3000
# 33/33 - 0s - loss: 0.0065 - mean_absolute_error: 0.0065 - val_loss: 0.0948 - val_mean_absolute_error: 0.0948
# Epoch 313/3000
# 33/33 - 0s - loss: 0.0063 - mean_absolute_error: 0.0063 - val_loss: 0.0949 - val_mean_absolute_error: 0.0949
# Epoch 314/3000
# 33/33 - 0s - loss: 0.0063 - mean_absolute_error: 0.0063 - val_loss: 0.0951 - val_mean_absolute_error: 0.0951
# Epoch 315/3000
# 33/33 - 0s - loss: 0.0066 - mean_absolute_error: 0.0066 - val_loss: 0.0961 - val_mean_absolute_error: 0.0961
# Epoch 316/3000
# 33/33 - 0s - loss: 0.0063 - mean_absolute_error: 0.0063 - val_loss: 0.0955 - val_mean_absolute_error: 0.0955
# Epoch 317/3000
# 33/33 - 0s - loss: 0.0070 - mean_absolute_error: 0.0070 - val_loss: 0.0959 - val_mean_absolute_error: 0.0959
# Epoch 318/3000
# 33/33 - 0s - loss: 0.0064 - mean_absolute_error: 0.0064 - val_loss: 0.0970 - val_mean_absolute_error: 0.0970
# Epoch 319/3000
# 33/33 - 0s - loss: 0.0064 - mean_absolute_error: 0.0064 - val_loss: 0.0951 - val_mean_absolute_error: 0.0951
# Epoch 320/3000
# 33/33 - 0s - loss: 0.0058 - mean_absolute_error: 0.0058 - val_loss: 0.0954 - val_mean_absolute_error: 0.0954
# Epoch 321/3000
# 33/33 - 0s - loss: 0.0061 - mean_absolute_error: 0.0061 - val_loss: 0.0959 - val_mean_absolute_error: 0.0959
# Epoch 322/3000
# 33/33 - 0s - loss: 0.0061 - mean_absolute_error: 0.0061 - val_loss: 0.0948 - val_mean_absolute_error: 0.0948
# Epoch 323/3000
# 33/33 - 0s - loss: 0.0058 - mean_absolute_error: 0.0058 - val_loss: 0.0951 - val_mean_absolute_error: 0.0951
# Epoch 324/3000
# 33/33 - 0s - loss: 0.0061 - mean_absolute_error: 0.0061 - val_loss: 0.0956 - val_mean_absolute_error: 0.0956
# Epoch 325/3000
# 33/33 - 0s - loss: 0.0059 - mean_absolute_error: 0.0059 - val_loss: 0.0955 - val_mean_absolute_error: 0.0955
# Epoch 326/3000
# 33/33 - 0s - loss: 0.0058 - mean_absolute_error: 0.0058 - val_loss: 0.0952 - val_mean_absolute_error: 0.0952
# Epoch 327/3000
# 33/33 - 0s - loss: 0.0059 - mean_absolute_error: 0.0059 - val_loss: 0.0945 - val_mean_absolute_error: 0.0945
# Epoch 328/3000
# 33/33 - 0s - loss: 0.0062 - mean_absolute_error: 0.0062 - val_loss: 0.0951 - val_mean_absolute_error: 0.0951
# Epoch 329/3000
# 33/33 - 0s - loss: 0.0080 - mean_absolute_error: 0.0080 - val_loss: 0.0952 - val_mean_absolute_error: 0.0952
# Epoch 330/3000
# 33/33 - 0s - loss: 0.0079 - mean_absolute_error: 0.0079 - val_loss: 0.0951 - val_mean_absolute_error: 0.0951
# Epoch 331/3000
# 33/33 - 0s - loss: 0.0068 - mean_absolute_error: 0.0068 - val_loss: 0.0950 - val_mean_absolute_error: 0.0950
# Epoch 332/3000
# 33/33 - 0s - loss: 0.0060 - mean_absolute_error: 0.0060 - val_loss: 0.0940 - val_mean_absolute_error: 0.0940
# Epoch 333/3000
# 33/33 - 0s - loss: 0.0063 - mean_absolute_error: 0.0063 - val_loss: 0.0943 - val_mean_absolute_error: 0.0943
# Epoch 334/3000
# 33/33 - 0s - loss: 0.0063 - mean_absolute_error: 0.0063 - val_loss: 0.0949 - val_mean_absolute_error: 0.0949
# Epoch 335/3000
# 33/33 - 0s - loss: 0.0082 - mean_absolute_error: 0.0082 - val_loss: 0.0942 - val_mean_absolute_error: 0.0942
# Epoch 336/3000
# 33/33 - 0s - loss: 0.0067 - mean_absolute_error: 0.0067 - val_loss: 0.0948 - val_mean_absolute_error: 0.0948
# Epoch 337/3000
# 33/33 - 0s - loss: 0.0063 - mean_absolute_error: 0.0063 - val_loss: 0.0937 - val_mean_absolute_error: 0.0937
# Epoch 338/3000
# 33/33 - 0s - loss: 0.0057 - mean_absolute_error: 0.0057 - val_loss: 0.0953 - val_mean_absolute_error: 0.0953
# Epoch 339/3000
# 33/33 - 0s - loss: 0.0056 - mean_absolute_error: 0.0056 - val_loss: 0.0938 - val_mean_absolute_error: 0.0938
# Epoch 340/3000
# 33/33 - 0s - loss: 0.0066 - mean_absolute_error: 0.0066 - val_loss: 0.0930 - val_mean_absolute_error: 0.0930
# Epoch 341/3000
# 33/33 - 0s - loss: 0.0069 - mean_absolute_error: 0.0069 - val_loss: 0.0946 - val_mean_absolute_error: 0.0946
# Epoch 342/3000
# 33/33 - 0s - loss: 0.0059 - mean_absolute_error: 0.0059 - val_loss: 0.0937 - val_mean_absolute_error: 0.0937
# Epoch 343/3000
# 33/33 - 0s - loss: 0.0065 - mean_absolute_error: 0.0065 - val_loss: 0.0945 - val_mean_absolute_error: 0.0945
# Epoch 344/3000
# 33/33 - 0s - loss: 0.0063 - mean_absolute_error: 0.0063 - val_loss: 0.0940 - val_mean_absolute_error: 0.0940
# Epoch 345/3000
# 33/33 - 0s - loss: 0.0065 - mean_absolute_error: 0.0065 - val_loss: 0.0946 - val_mean_absolute_error: 0.0946
# Epoch 346/3000
# 33/33 - 0s - loss: 0.0060 - mean_absolute_error: 0.0060 - val_loss: 0.0946 - val_mean_absolute_error: 0.0946
# Epoch 347/3000
# 33/33 - 0s - loss: 0.0057 - mean_absolute_error: 0.0057 - val_loss: 0.0952 - val_mean_absolute_error: 0.0952
# Epoch 348/3000
# 33/33 - 0s - loss: 0.0062 - mean_absolute_error: 0.0062 - val_loss: 0.0940 - val_mean_absolute_error: 0.0940
# Epoch 349/3000
# 33/33 - 0s - loss: 0.0061 - mean_absolute_error: 0.0061 - val_loss: 0.0949 - val_mean_absolute_error: 0.0949
# Epoch 350/3000
# 33/33 - 0s - loss: 0.0061 - mean_absolute_error: 0.0061 - val_loss: 0.0957 - val_mean_absolute_error: 0.0957
# Epoch 351/3000
# 33/33 - 0s - loss: 0.0076 - mean_absolute_error: 0.0076 - val_loss: 0.0943 - val_mean_absolute_error: 0.0943
# Epoch 352/3000
# 33/33 - 0s - loss: 0.0067 - mean_absolute_error: 0.0067 - val_loss: 0.0946 - val_mean_absolute_error: 0.0946
# Epoch 353/3000
# 33/33 - 0s - loss: 0.0065 - mean_absolute_error: 0.0065 - val_loss: 0.0958 - val_mean_absolute_error: 0.0958
# Epoch 354/3000
# 33/33 - 0s - loss: 0.0062 - mean_absolute_error: 0.0062 - val_loss: 0.0951 - val_mean_absolute_error: 0.0951
# Epoch 355/3000
# 33/33 - 0s - loss: 0.0064 - mean_absolute_error: 0.0064 - val_loss: 0.0946 - val_mean_absolute_error: 0.0946
# Epoch 356/3000
# 33/33 - 0s - loss: 0.0060 - mean_absolute_error: 0.0060 - val_loss: 0.0947 - val_mean_absolute_error: 0.0947
# Epoch 357/3000
# 33/33 - 0s - loss: 0.0059 - mean_absolute_error: 0.0059 - val_loss: 0.0953 - val_mean_absolute_error: 0.0953
# Epoch 358/3000
# 33/33 - 0s - loss: 0.0065 - mean_absolute_error: 0.0065 - val_loss: 0.0949 - val_mean_absolute_error: 0.0949
# Epoch 359/3000
# 33/33 - 0s - loss: 0.0062 - mean_absolute_error: 0.0062 - val_loss: 0.0946 - val_mean_absolute_error: 0.0946
# Epoch 360/3000
# 33/33 - 0s - loss: 0.0060 - mean_absolute_error: 0.0060 - val_loss: 0.0949 - val_mean_absolute_error: 0.0949
# Epoch 361/3000
# 33/33 - 0s - loss: 0.0058 - mean_absolute_error: 0.0058 - val_loss: 0.0943 - val_mean_absolute_error: 0.0943
# Epoch 362/3000
# 33/33 - 0s - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.0949 - val_mean_absolute_error: 0.0949
# Epoch 363/3000
# 33/33 - 0s - loss: 0.0062 - mean_absolute_error: 0.0062 - val_loss: 0.0950 - val_mean_absolute_error: 0.0950
# Epoch 364/3000
# 33/33 - 0s - loss: 0.0061 - mean_absolute_error: 0.0061 - val_loss: 0.0950 - val_mean_absolute_error: 0.0950
# Epoch 365/3000
# 33/33 - 0s - loss: 0.0059 - mean_absolute_error: 0.0059 - val_loss: 0.0946 - val_mean_absolute_error: 0.0946
# Epoch 366/3000
# 33/33 - 0s - loss: 0.0058 - mean_absolute_error: 0.0058 - val_loss: 0.0955 - val_mean_absolute_error: 0.0955
# Epoch 367/3000
# 33/33 - 0s - loss: 0.0057 - mean_absolute_error: 0.0057 - val_loss: 0.0954 - val_mean_absolute_error: 0.0954
# Epoch 368/3000
# 33/33 - 0s - loss: 0.0063 - mean_absolute_error: 0.0063 - val_loss: 0.0953 - val_mean_absolute_error: 0.0953
# Epoch 369/3000
# 33/33 - 0s - loss: 0.0059 - mean_absolute_error: 0.0059 - val_loss: 0.0951 - val_mean_absolute_error: 0.0951
# Epoch 370/3000
# 33/33 - 0s - loss: 0.0066 - mean_absolute_error: 0.0066 - val_loss: 0.0950 - val_mean_absolute_error: 0.0950
# Epoch 371/3000
# 33/33 - 0s - loss: 0.0062 - mean_absolute_error: 0.0062 - val_loss: 0.0948 - val_mean_absolute_error: 0.0948
# Epoch 372/3000
# 33/33 - 0s - loss: 0.0063 - mean_absolute_error: 0.0063 - val_loss: 0.0952 - val_mean_absolute_error: 0.0952
# Epoch 373/3000
# 33/33 - 0s - loss: 0.0062 - mean_absolute_error: 0.0062 - val_loss: 0.0941 - val_mean_absolute_error: 0.0941
# Epoch 374/3000
# 33/33 - 0s - loss: 0.0062 - mean_absolute_error: 0.0062 - val_loss: 0.0954 - val_mean_absolute_error: 0.0954
# Epoch 375/3000
# 33/33 - 0s - loss: 0.0061 - mean_absolute_error: 0.0061 - val_loss: 0.0950 - val_mean_absolute_error: 0.0950
# Epoch 376/3000
# 33/33 - 0s - loss: 0.0055 - mean_absolute_error: 0.0055 - val_loss: 0.0946 - val_mean_absolute_error: 0.0946
# Epoch 377/3000
# 33/33 - 0s - loss: 0.0053 - mean_absolute_error: 0.0053 - val_loss: 0.0953 - val_mean_absolute_error: 0.0953
# Epoch 378/3000
# 33/33 - 0s - loss: 0.0059 - mean_absolute_error: 0.0059 - val_loss: 0.0938 - val_mean_absolute_error: 0.0938
# Epoch 379/3000
# 33/33 - 0s - loss: 0.0064 - mean_absolute_error: 0.0064 - val_loss: 0.0952 - val_mean_absolute_error: 0.0952
# Epoch 380/3000
# 33/33 - 0s - loss: 0.0074 - mean_absolute_error: 0.0074 - val_loss: 0.0942 - val_mean_absolute_error: 0.0942
# Epoch 381/3000
# 33/33 - 0s - loss: 0.0066 - mean_absolute_error: 0.0066 - val_loss: 0.0945 - val_mean_absolute_error: 0.0945
# Epoch 382/3000
# 33/33 - 0s - loss: 0.0060 - mean_absolute_error: 0.0060 - val_loss: 0.0942 - val_mean_absolute_error: 0.0942
# Epoch 383/3000
# 33/33 - 0s - loss: 0.0059 - mean_absolute_error: 0.0059 - val_loss: 0.0947 - val_mean_absolute_error: 0.0947
# Epoch 384/3000
# 33/33 - 0s - loss: 0.0060 - mean_absolute_error: 0.0060 - val_loss: 0.0942 - val_mean_absolute_error: 0.0942
# Epoch 385/3000
# 33/33 - 0s - loss: 0.0059 - mean_absolute_error: 0.0059 - val_loss: 0.0951 - val_mean_absolute_error: 0.0951
# Epoch 386/3000
# 33/33 - 0s - loss: 0.0060 - mean_absolute_error: 0.0060 - val_loss: 0.0942 - val_mean_absolute_error: 0.0942
# Epoch 387/3000
# 33/33 - 0s - loss: 0.0062 - mean_absolute_error: 0.0062 - val_loss: 0.0941 - val_mean_absolute_error: 0.0941
# Epoch 388/3000
# 33/33 - 0s - loss: 0.0064 - mean_absolute_error: 0.0064 - val_loss: 0.0939 - val_mean_absolute_error: 0.0939
# Epoch 389/3000
# 33/33 - 0s - loss: 0.0061 - mean_absolute_error: 0.0061 - val_loss: 0.0939 - val_mean_absolute_error: 0.0939
# Epoch 390/3000
# 33/33 - 0s - loss: 0.0061 - mean_absolute_error: 0.0061 - val_loss: 0.0936 - val_mean_absolute_error: 0.0936
# Epoch 391/3000
# 33/33 - 0s - loss: 0.0057 - mean_absolute_error: 0.0057 - val_loss: 0.0950 - val_mean_absolute_error: 0.0950
# Epoch 392/3000
# 33/33 - 0s - loss: 0.0066 - mean_absolute_error: 0.0066 - val_loss: 0.0937 - val_mean_absolute_error: 0.0937
# Epoch 393/3000
# 33/33 - 0s - loss: 0.0061 - mean_absolute_error: 0.0061 - val_loss: 0.0949 - val_mean_absolute_error: 0.0949
# Epoch 394/3000
# 33/33 - 0s - loss: 0.0061 - mean_absolute_error: 0.0061 - val_loss: 0.0947 - val_mean_absolute_error: 0.0947
# Epoch 395/3000
# 33/33 - 0s - loss: 0.0059 - mean_absolute_error: 0.0059 - val_loss: 0.0952 - val_mean_absolute_error: 0.0952
# Epoch 396/3000
# 33/33 - 0s - loss: 0.0056 - mean_absolute_error: 0.0056 - val_loss: 0.0947 - val_mean_absolute_error: 0.0947
# Epoch 397/3000
# 33/33 - 0s - loss: 0.0057 - mean_absolute_error: 0.0057 - val_loss: 0.0964 - val_mean_absolute_error: 0.0964
# Epoch 398/3000
# 33/33 - 0s - loss: 0.0060 - mean_absolute_error: 0.0060 - val_loss: 0.0952 - val_mean_absolute_error: 0.0952
# Epoch 399/3000
# 33/33 - 0s - loss: 0.0069 - mean_absolute_error: 0.0069 - val_loss: 0.0941 - val_mean_absolute_error: 0.0941
# Epoch 400/3000
# 33/33 - 0s - loss: 0.0067 - mean_absolute_error: 0.0067 - val_loss: 0.0947 - val_mean_absolute_error: 0.0947
# Epoch 401/3000
# 33/33 - 0s - loss: 0.0059 - mean_absolute_error: 0.0059 - val_loss: 0.0941 - val_mean_absolute_error: 0.0941
# Epoch 402/3000
# 33/33 - 0s - loss: 0.0067 - mean_absolute_error: 0.0067 - val_loss: 0.0941 - val_mean_absolute_error: 0.0941
# Epoch 403/3000
# 33/33 - 0s - loss: 0.0073 - mean_absolute_error: 0.0073 - val_loss: 0.0942 - val_mean_absolute_error: 0.0942
# Epoch 404/3000
# 33/33 - 0s - loss: 0.0060 - mean_absolute_error: 0.0060 - val_loss: 0.0935 - val_mean_absolute_error: 0.0935
# Epoch 405/3000
# 33/33 - 0s - loss: 0.0055 - mean_absolute_error: 0.0055 - val_loss: 0.0942 - val_mean_absolute_error: 0.0942
# Epoch 406/3000
# 33/33 - 0s - loss: 0.0061 - mean_absolute_error: 0.0061 - val_loss: 0.0945 - val_mean_absolute_error: 0.0945
# Epoch 407/3000
# 33/33 - 0s - loss: 0.0069 - mean_absolute_error: 0.0069 - val_loss: 0.0945 - val_mean_absolute_error: 0.0945
# Epoch 408/3000
# 33/33 - 0s - loss: 0.0064 - mean_absolute_error: 0.0064 - val_loss: 0.0943 - val_mean_absolute_error: 0.0943
# Epoch 409/3000
# 33/33 - 0s - loss: 0.0063 - mean_absolute_error: 0.0063 - val_loss: 0.0944 - val_mean_absolute_error: 0.0944
# Epoch 410/3000
# 33/33 - 0s - loss: 0.0064 - mean_absolute_error: 0.0064 - val_loss: 0.0942 - val_mean_absolute_error: 0.0942
# Epoch 411/3000
# 33/33 - 0s - loss: 0.0060 - mean_absolute_error: 0.0060 - val_loss: 0.0944 - val_mean_absolute_error: 0.0944
# Epoch 412/3000
# 33/33 - 0s - loss: 0.0061 - mean_absolute_error: 0.0061 - val_loss: 0.0946 - val_mean_absolute_error: 0.0946
# Epoch 413/3000
# 33/33 - 0s - loss: 0.0056 - mean_absolute_error: 0.0056 - val_loss: 0.0946 - val_mean_absolute_error: 0.0946
# Epoch 414/3000
# 33/33 - 0s - loss: 0.0071 - mean_absolute_error: 0.0071 - val_loss: 0.0940 - val_mean_absolute_error: 0.0940
# Epoch 415/3000
# 33/33 - 0s - loss: 0.0056 - mean_absolute_error: 0.0056 - val_loss: 0.0948 - val_mean_absolute_error: 0.0948
# Epoch 416/3000
# 33/33 - 0s - loss: 0.0061 - mean_absolute_error: 0.0061 - val_loss: 0.0945 - val_mean_absolute_error: 0.0945
# Epoch 417/3000
# 33/33 - 0s - loss: 0.0058 - mean_absolute_error: 0.0058 - val_loss: 0.0954 - val_mean_absolute_error: 0.0954
# Epoch 418/3000
# 33/33 - 0s - loss: 0.0066 - mean_absolute_error: 0.0066 - val_loss: 0.0951 - val_mean_absolute_error: 0.0951
# Epoch 419/3000
# 33/33 - 0s - loss: 0.0065 - mean_absolute_error: 0.0065 - val_loss: 0.0945 - val_mean_absolute_error: 0.0945
# Epoch 420/3000
# 33/33 - 0s - loss: 0.0074 - mean_absolute_error: 0.0074 - val_loss: 0.0948 - val_mean_absolute_error: 0.0948
# Epoch 421/3000
# 33/33 - 0s - loss: 0.0066 - mean_absolute_error: 0.0066 - val_loss: 0.0947 - val_mean_absolute_error: 0.0947
# Epoch 422/3000
# 33/33 - 0s - loss: 0.0060 - mean_absolute_error: 0.0060 - val_loss: 0.0937 - val_mean_absolute_error: 0.0937
# Epoch 423/3000
# 33/33 - 0s - loss: 0.0058 - mean_absolute_error: 0.0058 - val_loss: 0.0943 - val_mean_absolute_error: 0.0943
# Epoch 424/3000
# 33/33 - 0s - loss: 0.0059 - mean_absolute_error: 0.0059 - val_loss: 0.0948 - val_mean_absolute_error: 0.0948
# Epoch 425/3000
# 33/33 - 0s - loss: 0.0062 - mean_absolute_error: 0.0062 - val_loss: 0.0944 - val_mean_absolute_error: 0.0944
# Epoch 426/3000
# 33/33 - 0s - loss: 0.0067 - mean_absolute_error: 0.0067 - val_loss: 0.0952 - val_mean_absolute_error: 0.0952
# Epoch 427/3000
# 33/33 - 0s - loss: 0.0062 - mean_absolute_error: 0.0062 - val_loss: 0.0943 - val_mean_absolute_error: 0.0943
# Epoch 428/3000
# 33/33 - 0s - loss: 0.0060 - mean_absolute_error: 0.0060 - val_loss: 0.0945 - val_mean_absolute_error: 0.0945
# Epoch 429/3000
# 33/33 - 0s - loss: 0.0055 - mean_absolute_error: 0.0055 - val_loss: 0.0944 - val_mean_absolute_error: 0.0944
# Epoch 430/3000
# 33/33 - 0s - loss: 0.0061 - mean_absolute_error: 0.0061 - val_loss: 0.0936 - val_mean_absolute_error: 0.0936
# Epoch 431/3000
# 33/33 - 0s - loss: 0.0065 - mean_absolute_error: 0.0065 - val_loss: 0.0940 - val_mean_absolute_error: 0.0940
# Epoch 432/3000
# 33/33 - 0s - loss: 0.0056 - mean_absolute_error: 0.0056 - val_loss: 0.0946 - val_mean_absolute_error: 0.0946
# Epoch 433/3000
# 33/33 - 0s - loss: 0.0055 - mean_absolute_error: 0.0055 - val_loss: 0.0943 - val_mean_absolute_error: 0.0943
# Epoch 434/3000
# 33/33 - 0s - loss: 0.0069 - mean_absolute_error: 0.0069 - val_loss: 0.0942 - val_mean_absolute_error: 0.0942
# Epoch 435/3000
# 33/33 - 0s - loss: 0.0064 - mean_absolute_error: 0.0064 - val_loss: 0.0947 - val_mean_absolute_error: 0.0947
# Epoch 436/3000
# 33/33 - 0s - loss: 0.0072 - mean_absolute_error: 0.0072 - val_loss: 0.0946 - val_mean_absolute_error: 0.0946
# Epoch 437/3000
# 33/33 - 0s - loss: 0.0061 - mean_absolute_error: 0.0061 - val_loss: 0.0944 - val_mean_absolute_error: 0.0944
# Epoch 438/3000
# 33/33 - 0s - loss: 0.0067 - mean_absolute_error: 0.0067 - val_loss: 0.0947 - val_mean_absolute_error: 0.0947
# Epoch 439/3000
# 33/33 - 0s - loss: 0.0060 - mean_absolute_error: 0.0060 - val_loss: 0.0944 - val_mean_absolute_error: 0.0944
# Epoch 440/3000
# 33/33 - 0s - loss: 0.0057 - mean_absolute_error: 0.0057 - val_loss: 0.0941 - val_mean_absolute_error: 0.0941
# Restoring model weights from the end of the best epoch.
# Epoch 00440: early stopping

# %%
pred=model.predict(X_test)
print(mean_absolute_error(y_test,pred))
# Out:
# 0.09383534357808736

# %%
f=open('SinglePropertyPrediction-test-formula_energy-ssub-AI-mae.csv','w')
f.write('id,target,prediction\n')
for i,j,k in zip(test_ids,y_test,pred):
    line=str(i)+','+str(j)+','+str(k)+'\n'
    f.write(line)
f.close()
