# %%
#https://github.com/wolverton-research-group/qmpy/blob/master/qmpy/data/thermodata/ssub.dat
from jarvis.db.figshare import  get_request_data
dat = get_request_data(js_tag="ssub.json",url="https://figshare.com/ndownloader/files/40084921")
# Out:
# Loading the zipfile...
# Loading completed.

# %%
import pandas as pd
df = pd.DataFrame(dat)

# %%
df
# Out:
#         id  formula_energy formula
# 0      465   -2.841796e+00   CaO4W
# 1     1197    1.766051e-09      Ho
# 2     1759   -3.555857e-01    PbTe
# 3     1454   -9.540103e-01    MoS2
# 4      218   -6.564038e-02    BeH2
# ...    ...             ...     ...
# 1722  1482   -1.892842e+00     NZr
# 1723   773   -2.404511e+00  CrLiO2
# 1724   251   -4.946426e-01   BiNa3
# 1725   328   -7.213532e-01   Br4Ge
# 1726  1960   -2.740610e+00   AlClO
#
# [1727 rows x 3 columns]

# %%
import json,zipfile
import numpy as np
path = "../../benchmarks/AI/SinglePropertyPrediction/ssub_formula_energy.json.zip"
js_tag = "ssub_formula_energy.json"
id_data = json.loads(zipfile.ZipFile(path).read(js_tag))

# %%
id_data.keys()
# Out:
# dict_keys(['train', 'test'])

# %%
train_ids = np.array(list(id_data['train'].keys()),dtype='int')
test_ids = np.array(list(id_data['test'].keys()),dtype='int')

# %%
print(len(train_ids),len(test_ids),len(train_ids)+len(test_ids))
# Out:
# 1381 345 1726

# %%
train_df = df[df['id'].isin(train_ids)]
test_df = df[df['id'].isin(test_ids)]

# %%
len(train_df), len(val_df), len(test_df)
# Out:
# (1036, 345, 345)

# %%
# %%time
from jarvis.ai.descriptors.elemental import get_element_fraction_desc
from jarvis.ai.descriptors.cfid import CFID,get_chem_only_descriptors
from tqdm import tqdm
import numpy as np
from sklearn.model_selection import train_test_split
import lightgbm as lgb
from sklearn.metrics import mean_absolute_error

lgbm = lgb.LGBMRegressor(
    # device="gpu",
    n_estimators=1170,
    learning_rate=0.15,
    num_leaves=273,
)
X_train=[]
y_train=[]
X_test=[]
y_test=[]
train_ids=[]
test_ids=[]
for i,ii in train_df.iterrows():
    desc=get_element_fraction_desc(ii['formula'])
    #desc=get_chem_only_descriptors(ii['composition'])[0]
    X_train.append(desc)
    y_train.append(ii['formula_energy'])
    train_ids.append(ii['id'])
for i,ii in test_df.iterrows():
    desc=get_element_fraction_desc(ii['formula'])
    #desc=get_chem_only_descriptors(ii['composition'])[0]
    X_test.append(desc)
    y_test.append(ii['formula_energy'])
    test_ids.append(ii['id'])
    
X_train=np.array(X_train,dtype='float')
y_train=np.array(y_train,dtype='float')
X_test=np.array(X_test,dtype='float')
y_test=np.array(y_test,dtype='float')
lgbm.fit(X_train,y_train)
pred=lgbm.predict(X_test)
print (mean_absolute_error(y_test,pred))
# Out:
# 0.38072016830809796
# CPU times: user 4min 10s, sys: 9.91 ms, total: 4min 10s
# Wall time: 15.9 s

# %%
import os
f=open('AI-SinglePropertyPrediction-formula_energy-ssub-test-mae.csv','w')
f.write('id,target,prediction\n')
for i,j,k in zip(test_ids,y_test,pred):
    line=str(i)+','+str(j)+','+str(k)+'\n'
    f.write(line)
f.close()
cmd = 'zip AI-SinglePropertyPrediction-formula_energy-ssub-test-mae.csv.zip AI-SinglePropertyPrediction-formula_energy-ssub-test-mae.csv'
os.system(cmd)
cmd='rm AI-SinglePropertyPrediction-formula_energy-ssub-test-mae.csv'
os.system(cmd)
# Out:
#   adding: AI-SinglePropertyPrediction-formula_energy-ssub-test-mae.csv (deflated 54%)
# 0

# %%
import data_utils
from jarvis.ai.descriptors.elemental import get_element_fraction_desc
from jarvis.ai.descriptors.cfid import CFID,get_chem_only_descriptors
from tqdm import tqdm
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

elements = ['H', 'Li', 'Be', 'B', 'C', 'N', 'O', 'F', 'Na', 'Mg', 'Al', 'Si', 'P', 'S', 'Cl', 'K',
 'Ca', 'Sc', 'Ti', 'V', 'Cr', 'Mn', 'Fe', 'Co', 'Ni', 'Cu', 'Zn', 'Ga', 'Ge', 'As', 'Se',
 'Br', 'Kr', 'Rb', 'Sr', 'Y', 'Zr', 'Nb', 'Mo', 'Tc', 'Ru', 'Rh', 'Pd', 'Ag', 'Cd', 'In',
 'Sn', 'Sb', 'Te', 'I', 'Xe', 'Cs', 'Ba', 'La', 'Ce', 'Pr', 'Nd', 'Pm', 'Sm', 'Eu', 'Gd',
 'Tb', 'Dy', 'Ho', 'Er', 'Tm', 'Yb', 'Lu', 'Hf', 'Ta', 'W', 'Re', 'Os', 'Ir', 'Pt', 'Au',
 'Hg', 'Tl', 'Pb', 'Bi', 'Ac','Th', 'Pa', 'U', 'Np', 'Pu']

def formula_to_ef(df):
    df['comp_dict'] = df['formula'].apply(lambda x: data_utils.parse_formula(x))
    df['comp_fractions'] = df['comp_dict'].apply(lambda x: data_utils.get_fractions(x))
    df = df[~df['comp_fractions'].isnull()]

    for i,e in enumerate(elements):
        df[e] = [ x[i] for x in df['comp_fractions']]

    X_df = np.array(df[elements],dtype='float')    
    y_df = np.array(df['formula_energy'],dtype='float')
    list_df = list(df['id'])

    return X_df, y_df, list_df

# %%
X_train, y_train, train_ids = formula_to_ef(train_df)
X_val, y_val, val_ids = formula_to_ef(val_df)
X_test, y_test, test_ids = formula_to_ef(test_df)
# Out:
# /tmp/ipykernel_30131/1972034185.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['comp_dict'] = df['formula'].apply(lambda x: data_utils.parse_formula(x))
# /tmp/ipykernel_30131/1972034185.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['comp_fractions'] = df['comp_dict'].apply(lambda x: data_utils.get_fractions(x))
# /tmp/ipykernel_30131/1972034185.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[e] = [ x[i] for x in df['comp_fractions']]

# %%
import numpy as np
np.random.seed(1234567)
import tensorflow as tf
tf.random.set_seed(1234567)
import random
random.seed(1234567)

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LeakyReLU
from tensorflow.keras.layers import Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Activation
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import mean_absolute_error, mean_squared_error
# Out:
# 2023-05-19 12:06:35.398277: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-05-19 12:06:35.493123: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-05-19 12:06:35.493139: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
#Network from "ElemNet: Deep Learning the Chemistry of Materials From Only Elemental Composition"
#Link to paper: https://www.nature.com/articles/s41598-018-35934-y
in_layer = Input(shape=(X_train.shape[1],))

layer_1 = Dense(1024)(in_layer)
layer_1 = Activation('relu')(layer_1)

layer_2 = Dense(1024)(layer_1)
layer_2 = Activation('relu')(layer_2)

layer_3 = Dense(1024)(layer_2)
layer_3 = Activation('relu')(layer_3)

layer_4 = Dense(1024)(layer_3)
layer_4 = Activation('relu')(layer_4)
layer_4 = Dropout(0.2)(layer_4, training=True)

layer_5 = Dense(512)(layer_4)
layer_5 = Activation('relu')(layer_5)

layer_6 = Dense(512)(layer_5)
layer_6 = Activation('relu')(layer_6)

layer_7 = Dense(512)(layer_6)
layer_7 = Activation('relu')(layer_7)
layer_7 = Dropout(0.1)(layer_7, training=True)

layer_8 = Dense(256)(layer_7)
layer_8 = Activation('relu')(layer_8)

layer_9 = Dense(256)(layer_8)
layer_9 = Activation('relu')(layer_9)

layer_10 = Dense(256)(layer_9)
layer_10 = Activation('relu')(layer_10)
layer_10 = Dropout(0.3)(layer_10, training=True)

layer_11 = Dense(128)(layer_10)
layer_11 = Activation('relu')(layer_11)

layer_12 = Dense(128)(layer_11)
layer_12 = Activation('relu')(layer_12)

layer_13 = Dense(128)(layer_12)
layer_13 = Activation('relu')(layer_13)
layer_13 = Dropout(0.2)(layer_13, training=True)

layer_14 = Dense(64)(layer_13)
layer_14 = Activation('relu')(layer_14)

layer_15 = Dense(64)(layer_14)
layer_15 = Activation('relu')(layer_15)

layer_16 = Dense(32)(layer_15)
layer_16 = Activation('relu')(layer_16)

out_layer = Dense(1)(layer_16)

model = Model(inputs=in_layer, outputs=out_layer)

adam = optimizers.Adam(lr=0.0001)
model.compile(loss=tf.keras.losses.mean_absolute_error, optimizer=adam, metrics=['mean_absolute_error'])

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=100, restore_best_weights=True)
# Out:
# 2023-05-19 12:06:41.040467: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:961] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-19 12:06:41.040714: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-05-19 12:06:41.040775: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2023-05-19 12:06:41.040816: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2023-05-19 12:06:41.040871: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2023-05-19 12:06:41.040914: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2023-05-19 12:06:41.040954: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2023-05-19 12:06:41.040994: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2023-05-19 12:06:41.041032: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2023-05-19 12:06:41.041038: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2023-05-19 12:06:41.041800: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/kamalch/miniconda3/envs/gpaw/lib/python3.8/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
# %%time
model.fit(X_train, y_train, verbose=2, validation_data=(X_val, y_val), epochs=3000, batch_size=32, callbacks=[es])
# Out:
# Epoch 1/3000
# 33/33 - 0s - loss: 0.1741 - mean_absolute_error: 0.1741 - val_loss: 0.2759 - val_mean_absolute_error: 0.2759 - 473ms/epoch - 14ms/step
# Epoch 2/3000
# 33/33 - 0s - loss: 0.1832 - mean_absolute_error: 0.1832 - val_loss: 0.2639 - val_mean_absolute_error: 0.2639 - 474ms/epoch - 14ms/step
# Epoch 3/3000
# 33/33 - 0s - loss: 0.1772 - mean_absolute_error: 0.1772 - val_loss: 0.2985 - val_mean_absolute_error: 0.2985 - 482ms/epoch - 15ms/step
# Epoch 4/3000
# 33/33 - 0s - loss: 0.1788 - mean_absolute_error: 0.1788 - val_loss: 0.3021 - val_mean_absolute_error: 0.3021 - 478ms/epoch - 14ms/step
# Epoch 5/3000
# 33/33 - 1s - loss: 0.1557 - mean_absolute_error: 0.1557 - val_loss: 0.2580 - val_mean_absolute_error: 0.2580 - 500ms/epoch - 15ms/step
# Epoch 6/3000
# 33/33 - 1s - loss: 0.1561 - mean_absolute_error: 0.1561 - val_loss: 0.2771 - val_mean_absolute_error: 0.2771 - 570ms/epoch - 17ms/step
# Epoch 7/3000
# 33/33 - 0s - loss: 0.1450 - mean_absolute_error: 0.1450 - val_loss: 0.2710 - val_mean_absolute_error: 0.2710 - 481ms/epoch - 15ms/step
# Epoch 8/3000
# 33/33 - 0s - loss: 0.1484 - mean_absolute_error: 0.1484 - val_loss: 0.2730 - val_mean_absolute_error: 0.2730 - 461ms/epoch - 14ms/step
# Epoch 9/3000
# 33/33 - 0s - loss: 0.1604 - mean_absolute_error: 0.1604 - val_loss: 0.2746 - val_mean_absolute_error: 0.2746 - 457ms/epoch - 14ms/step
# Epoch 10/3000
# 33/33 - 0s - loss: 0.1506 - mean_absolute_error: 0.1506 - val_loss: 0.2590 - val_mean_absolute_error: 0.2590 - 459ms/epoch - 14ms/step
# Epoch 11/3000
# 33/33 - 0s - loss: 0.1698 - mean_absolute_error: 0.1698 - val_loss: 0.2628 - val_mean_absolute_error: 0.2628 - 461ms/epoch - 14ms/step
# Epoch 12/3000
# 33/33 - 1s - loss: 0.1468 - mean_absolute_error: 0.1468 - val_loss: 0.2546 - val_mean_absolute_error: 0.2546 - 508ms/epoch - 15ms/step
# Epoch 13/3000
# 33/33 - 0s - loss: 0.1488 - mean_absolute_error: 0.1488 - val_loss: 0.2631 - val_mean_absolute_error: 0.2631 - 481ms/epoch - 15ms/step
# Epoch 14/3000
# 33/33 - 0s - loss: 0.1374 - mean_absolute_error: 0.1374 - val_loss: 0.2541 - val_mean_absolute_error: 0.2541 - 450ms/epoch - 14ms/step
# Epoch 15/3000
# 33/33 - 0s - loss: 0.1491 - mean_absolute_error: 0.1491 - val_loss: 0.2647 - val_mean_absolute_error: 0.2647 - 454ms/epoch - 14ms/step
# Epoch 16/3000
# 33/33 - 0s - loss: 0.1365 - mean_absolute_error: 0.1365 - val_loss: 0.2662 - val_mean_absolute_error: 0.2662 - 448ms/epoch - 14ms/step
# Epoch 17/3000
# 33/33 - 0s - loss: 0.1490 - mean_absolute_error: 0.1490 - val_loss: 0.2711 - val_mean_absolute_error: 0.2711 - 454ms/epoch - 14ms/step
# Epoch 18/3000
# 33/33 - 0s - loss: 0.1406 - mean_absolute_error: 0.1406 - val_loss: 0.2630 - val_mean_absolute_error: 0.2630 - 451ms/epoch - 14ms/step
# Epoch 19/3000
# 33/33 - 0s - loss: 0.1543 - mean_absolute_error: 0.1543 - val_loss: 0.2523 - val_mean_absolute_error: 0.2523 - 464ms/epoch - 14ms/step
# Epoch 20/3000
# 33/33 - 0s - loss: 0.1415 - mean_absolute_error: 0.1415 - val_loss: 0.2496 - val_mean_absolute_error: 0.2496 - 468ms/epoch - 14ms/step
# Epoch 21/3000
# 33/33 - 0s - loss: 0.1340 - mean_absolute_error: 0.1340 - val_loss: 0.2516 - val_mean_absolute_error: 0.2516 - 461ms/epoch - 14ms/step
# Epoch 22/3000
# 33/33 - 0s - loss: 0.1304 - mean_absolute_error: 0.1304 - val_loss: 0.2528 - val_mean_absolute_error: 0.2528 - 474ms/epoch - 14ms/step
# Epoch 23/3000
# 33/33 - 0s - loss: 0.1247 - mean_absolute_error: 0.1247 - val_loss: 0.2559 - val_mean_absolute_error: 0.2559 - 464ms/epoch - 14ms/step
# Epoch 24/3000
# 33/33 - 0s - loss: 0.1516 - mean_absolute_error: 0.1516 - val_loss: 0.2607 - val_mean_absolute_error: 0.2607 - 481ms/epoch - 15ms/step
# Epoch 25/3000
# 33/33 - 0s - loss: 0.1271 - mean_absolute_error: 0.1271 - val_loss: 0.2473 - val_mean_absolute_error: 0.2473 - 467ms/epoch - 14ms/step
# Epoch 26/3000
# 33/33 - 0s - loss: 0.1296 - mean_absolute_error: 0.1296 - val_loss: 0.2363 - val_mean_absolute_error: 0.2363 - 471ms/epoch - 14ms/step
# Epoch 27/3000
# 33/33 - 0s - loss: 0.1323 - mean_absolute_error: 0.1323 - val_loss: 0.2443 - val_mean_absolute_error: 0.2443 - 469ms/epoch - 14ms/step
# Epoch 28/3000
# 33/33 - 0s - loss: 0.1269 - mean_absolute_error: 0.1269 - val_loss: 0.2456 - val_mean_absolute_error: 0.2456 - 473ms/epoch - 14ms/step
# Epoch 29/3000
# 33/33 - 0s - loss: 0.1289 - mean_absolute_error: 0.1289 - val_loss: 0.2451 - val_mean_absolute_error: 0.2451 - 483ms/epoch - 15ms/step
# Epoch 30/3000
# 33/33 - 0s - loss: 0.1369 - mean_absolute_error: 0.1369 - val_loss: 0.2930 - val_mean_absolute_error: 0.2930 - 470ms/epoch - 14ms/step
# Epoch 31/3000
# 33/33 - 0s - loss: 0.1515 - mean_absolute_error: 0.1515 - val_loss: 0.2430 - val_mean_absolute_error: 0.2430 - 465ms/epoch - 14ms/step
# Epoch 32/3000
# 33/33 - 0s - loss: 0.1368 - mean_absolute_error: 0.1368 - val_loss: 0.2480 - val_mean_absolute_error: 0.2480 - 488ms/epoch - 15ms/step
# Epoch 33/3000
# 33/33 - 0s - loss: 0.1244 - mean_absolute_error: 0.1244 - val_loss: 0.2471 - val_mean_absolute_error: 0.2471 - 464ms/epoch - 14ms/step
# Epoch 34/3000
# 33/33 - 0s - loss: 0.1223 - mean_absolute_error: 0.1223 - val_loss: 0.2553 - val_mean_absolute_error: 0.2553 - 487ms/epoch - 15ms/step
# Epoch 35/3000
# 33/33 - 0s - loss: 0.1240 - mean_absolute_error: 0.1240 - val_loss: 0.2267 - val_mean_absolute_error: 0.2267 - 463ms/epoch - 14ms/step
# Epoch 36/3000
# 33/33 - 0s - loss: 0.1302 - mean_absolute_error: 0.1302 - val_loss: 0.2479 - val_mean_absolute_error: 0.2479 - 453ms/epoch - 14ms/step
# Epoch 37/3000
# 33/33 - 0s - loss: 0.1258 - mean_absolute_error: 0.1258 - val_loss: 0.2394 - val_mean_absolute_error: 0.2394 - 452ms/epoch - 14ms/step
# Epoch 38/3000
# 33/33 - 0s - loss: 0.1176 - mean_absolute_error: 0.1176 - val_loss: 0.2456 - val_mean_absolute_error: 0.2456 - 450ms/epoch - 14ms/step
# Epoch 39/3000
# 33/33 - 0s - loss: 0.1086 - mean_absolute_error: 0.1086 - val_loss: 0.2386 - val_mean_absolute_error: 0.2386 - 447ms/epoch - 14ms/step
# Epoch 40/3000
# 33/33 - 0s - loss: 0.1289 - mean_absolute_error: 0.1289 - val_loss: 0.2495 - val_mean_absolute_error: 0.2495 - 454ms/epoch - 14ms/step
# Epoch 41/3000
# 33/33 - 0s - loss: 0.1471 - mean_absolute_error: 0.1471 - val_loss: 0.2482 - val_mean_absolute_error: 0.2482 - 458ms/epoch - 14ms/step
# Epoch 42/3000
# 33/33 - 0s - loss: 0.1209 - mean_absolute_error: 0.1209 - val_loss: 0.2592 - val_mean_absolute_error: 0.2592 - 451ms/epoch - 14ms/step
# Epoch 43/3000
# 33/33 - 0s - loss: 0.1399 - mean_absolute_error: 0.1399 - val_loss: 0.2475 - val_mean_absolute_error: 0.2475 - 457ms/epoch - 14ms/step
# Epoch 44/3000
# 33/33 - 0s - loss: 0.1271 - mean_absolute_error: 0.1271 - val_loss: 0.2376 - val_mean_absolute_error: 0.2376 - 449ms/epoch - 14ms/step
# Epoch 45/3000
# 33/33 - 0s - loss: 0.1171 - mean_absolute_error: 0.1171 - val_loss: 0.2509 - val_mean_absolute_error: 0.2509 - 456ms/epoch - 14ms/step
# Epoch 46/3000
# 33/33 - 0s - loss: 0.1217 - mean_absolute_error: 0.1217 - val_loss: 0.2487 - val_mean_absolute_error: 0.2487 - 455ms/epoch - 14ms/step
# Epoch 47/3000
# 33/33 - 0s - loss: 0.1143 - mean_absolute_error: 0.1143 - val_loss: 0.2387 - val_mean_absolute_error: 0.2387 - 455ms/epoch - 14ms/step
# Epoch 48/3000
# 33/33 - 0s - loss: 0.1168 - mean_absolute_error: 0.1168 - val_loss: 0.2361 - val_mean_absolute_error: 0.2361 - 459ms/epoch - 14ms/step
# Epoch 49/3000
# 33/33 - 0s - loss: 0.1075 - mean_absolute_error: 0.1075 - val_loss: 0.2550 - val_mean_absolute_error: 0.2550 - 464ms/epoch - 14ms/step
# Epoch 50/3000
# 33/33 - 0s - loss: 0.1248 - mean_absolute_error: 0.1248 - val_loss: 0.2321 - val_mean_absolute_error: 0.2321 - 483ms/epoch - 15ms/step
# Epoch 51/3000
# 33/33 - 0s - loss: 0.1113 - mean_absolute_error: 0.1113 - val_loss: 0.2655 - val_mean_absolute_error: 0.2655 - 492ms/epoch - 15ms/step
# Epoch 52/3000
# 33/33 - 0s - loss: 0.1219 - mean_absolute_error: 0.1219 - val_loss: 0.2558 - val_mean_absolute_error: 0.2558 - 468ms/epoch - 14ms/step
# Epoch 53/3000
# 33/33 - 0s - loss: 0.1155 - mean_absolute_error: 0.1155 - val_loss: 0.2405 - val_mean_absolute_error: 0.2405 - 458ms/epoch - 14ms/step
# Epoch 54/3000
# 33/33 - 0s - loss: 0.1127 - mean_absolute_error: 0.1127 - val_loss: 0.2430 - val_mean_absolute_error: 0.2430 - 464ms/epoch - 14ms/step
# Epoch 55/3000
# 33/33 - 0s - loss: 0.1102 - mean_absolute_error: 0.1102 - val_loss: 0.2322 - val_mean_absolute_error: 0.2322 - 454ms/epoch - 14ms/step
# Epoch 56/3000
# 33/33 - 0s - loss: 0.1087 - mean_absolute_error: 0.1087 - val_loss: 0.2380 - val_mean_absolute_error: 0.2380 - 455ms/epoch - 14ms/step
# Epoch 57/3000
# 33/33 - 0s - loss: 0.1096 - mean_absolute_error: 0.1096 - val_loss: 0.2323 - val_mean_absolute_error: 0.2323 - 457ms/epoch - 14ms/step
# Epoch 58/3000
# 33/33 - 0s - loss: 0.1179 - mean_absolute_error: 0.1179 - val_loss: 0.2417 - val_mean_absolute_error: 0.2417 - 456ms/epoch - 14ms/step
# Epoch 59/3000
# 33/33 - 0s - loss: 0.1139 - mean_absolute_error: 0.1139 - val_loss: 0.2447 - val_mean_absolute_error: 0.2447 - 470ms/epoch - 14ms/step
# Epoch 60/3000
# 33/33 - 0s - loss: 0.1054 - mean_absolute_error: 0.1054 - val_loss: 0.2415 - val_mean_absolute_error: 0.2415 - 466ms/epoch - 14ms/step
# Epoch 61/3000
# 33/33 - 0s - loss: 0.1055 - mean_absolute_error: 0.1055 - val_loss: 0.2388 - val_mean_absolute_error: 0.2388 - 473ms/epoch - 14ms/step
# Epoch 62/3000
# 33/33 - 1s - loss: 0.1033 - mean_absolute_error: 0.1033 - val_loss: 0.2313 - val_mean_absolute_error: 0.2313 - 522ms/epoch - 16ms/step
# Epoch 63/3000
# 33/33 - 0s - loss: 0.1124 - mean_absolute_error: 0.1124 - val_loss: 0.2264 - val_mean_absolute_error: 0.2264 - 498ms/epoch - 15ms/step
# Epoch 64/3000
# 33/33 - 0s - loss: 0.1097 - mean_absolute_error: 0.1097 - val_loss: 0.2392 - val_mean_absolute_error: 0.2392 - 489ms/epoch - 15ms/step
# Epoch 65/3000
# 33/33 - 0s - loss: 0.1022 - mean_absolute_error: 0.1022 - val_loss: 0.2579 - val_mean_absolute_error: 0.2579 - 463ms/epoch - 14ms/step
# Epoch 66/3000
# 33/33 - 0s - loss: 0.1061 - mean_absolute_error: 0.1061 - val_loss: 0.2376 - val_mean_absolute_error: 0.2376 - 466ms/epoch - 14ms/step
# Epoch 67/3000
# 33/33 - 1s - loss: 0.1054 - mean_absolute_error: 0.1054 - val_loss: 0.2350 - val_mean_absolute_error: 0.2350 - 503ms/epoch - 15ms/step
# Epoch 68/3000
# 33/33 - 0s - loss: 0.1121 - mean_absolute_error: 0.1121 - val_loss: 0.2505 - val_mean_absolute_error: 0.2505 - 475ms/epoch - 14ms/step
# Epoch 69/3000
# 33/33 - 0s - loss: 0.1070 - mean_absolute_error: 0.1070 - val_loss: 0.2430 - val_mean_absolute_error: 0.2430 - 469ms/epoch - 14ms/step
# Epoch 70/3000
# 33/33 - 1s - loss: 0.1207 - mean_absolute_error: 0.1207 - val_loss: 0.2240 - val_mean_absolute_error: 0.2240 - 502ms/epoch - 15ms/step
# Epoch 71/3000
# 33/33 - 1s - loss: 0.1008 - mean_absolute_error: 0.1008 - val_loss: 0.2465 - val_mean_absolute_error: 0.2465 - 518ms/epoch - 16ms/step
# Epoch 72/3000
# 33/33 - 1s - loss: 0.1110 - mean_absolute_error: 0.1110 - val_loss: 0.2288 - val_mean_absolute_error: 0.2288 - 504ms/epoch - 15ms/step
# Epoch 73/3000
# 33/33 - 1s - loss: 0.1015 - mean_absolute_error: 0.1015 - val_loss: 0.2263 - val_mean_absolute_error: 0.2263 - 529ms/epoch - 16ms/step
# Epoch 74/3000
# 33/33 - 1s - loss: 0.1060 - mean_absolute_error: 0.1060 - val_loss: 0.2311 - val_mean_absolute_error: 0.2311 - 503ms/epoch - 15ms/step
# Epoch 75/3000
# 33/33 - 0s - loss: 0.0987 - mean_absolute_error: 0.0987 - val_loss: 0.2255 - val_mean_absolute_error: 0.2255 - 474ms/epoch - 14ms/step
# Epoch 76/3000
# 33/33 - 0s - loss: 0.0988 - mean_absolute_error: 0.0988 - val_loss: 0.2194 - val_mean_absolute_error: 0.2194 - 491ms/epoch - 15ms/step
# Epoch 77/3000
# 33/33 - 0s - loss: 0.0988 - mean_absolute_error: 0.0988 - val_loss: 0.2765 - val_mean_absolute_error: 0.2765 - 477ms/epoch - 14ms/step
# Epoch 78/3000
# 33/33 - 0s - loss: 0.1277 - mean_absolute_error: 0.1277 - val_loss: 0.2362 - val_mean_absolute_error: 0.2362 - 475ms/epoch - 14ms/step
# Epoch 79/3000
# 33/33 - 0s - loss: 0.1241 - mean_absolute_error: 0.1241 - val_loss: 0.2628 - val_mean_absolute_error: 0.2628 - 484ms/epoch - 15ms/step
# Epoch 80/3000
# 33/33 - 0s - loss: 0.1070 - mean_absolute_error: 0.1070 - val_loss: 0.2212 - val_mean_absolute_error: 0.2212 - 478ms/epoch - 14ms/step
# Epoch 81/3000
# 33/33 - 0s - loss: 0.0957 - mean_absolute_error: 0.0957 - val_loss: 0.2308 - val_mean_absolute_error: 0.2308 - 474ms/epoch - 14ms/step
# Epoch 82/3000
# 33/33 - 1s - loss: 0.0919 - mean_absolute_error: 0.0919 - val_loss: 0.2130 - val_mean_absolute_error: 0.2130 - 501ms/epoch - 15ms/step
# Epoch 83/3000
# 33/33 - 0s - loss: 0.0928 - mean_absolute_error: 0.0928 - val_loss: 0.2315 - val_mean_absolute_error: 0.2315 - 495ms/epoch - 15ms/step
# Epoch 84/3000
# 33/33 - 1s - loss: 0.0972 - mean_absolute_error: 0.0972 - val_loss: 0.2314 - val_mean_absolute_error: 0.2314 - 613ms/epoch - 19ms/step
# Epoch 85/3000
# 33/33 - 1s - loss: 0.0958 - mean_absolute_error: 0.0958 - val_loss: 0.2212 - val_mean_absolute_error: 0.2212 - 597ms/epoch - 18ms/step
# Epoch 86/3000
# 33/33 - 1s - loss: 0.1074 - mean_absolute_error: 0.1074 - val_loss: 0.2282 - val_mean_absolute_error: 0.2282 - 552ms/epoch - 17ms/step
# Epoch 87/3000
# 33/33 - 1s - loss: 0.0980 - mean_absolute_error: 0.0980 - val_loss: 0.2234 - val_mean_absolute_error: 0.2234 - 516ms/epoch - 16ms/step
# Epoch 88/3000
# 33/33 - 0s - loss: 0.0967 - mean_absolute_error: 0.0967 - val_loss: 0.2298 - val_mean_absolute_error: 0.2298 - 499ms/epoch - 15ms/step
# Epoch 89/3000
# 33/33 - 1s - loss: 0.1195 - mean_absolute_error: 0.1195 - val_loss: 0.2227 - val_mean_absolute_error: 0.2227 - 510ms/epoch - 15ms/step
# Epoch 90/3000
# 33/33 - 1s - loss: 0.1283 - mean_absolute_error: 0.1283 - val_loss: 0.2204 - val_mean_absolute_error: 0.2204 - 510ms/epoch - 15ms/step
# Epoch 91/3000
# 33/33 - 1s - loss: 0.1029 - mean_absolute_error: 0.1029 - val_loss: 0.2177 - val_mean_absolute_error: 0.2177 - 506ms/epoch - 15ms/step
# Epoch 92/3000
# 33/33 - 0s - loss: 0.1292 - mean_absolute_error: 0.1292 - val_loss: 0.2348 - val_mean_absolute_error: 0.2348 - 481ms/epoch - 15ms/step
# Epoch 93/3000
# 33/33 - 0s - loss: 0.0972 - mean_absolute_error: 0.0972 - val_loss: 0.2097 - val_mean_absolute_error: 0.2097 - 486ms/epoch - 15ms/step
# Epoch 94/3000
# 33/33 - 0s - loss: 0.0943 - mean_absolute_error: 0.0943 - val_loss: 0.2238 - val_mean_absolute_error: 0.2238 - 484ms/epoch - 15ms/step
# Epoch 95/3000
# 33/33 - 0s - loss: 0.1126 - mean_absolute_error: 0.1126 - val_loss: 0.2265 - val_mean_absolute_error: 0.2265 - 491ms/epoch - 15ms/step
# Epoch 96/3000
# 33/33 - 0s - loss: 0.0943 - mean_absolute_error: 0.0943 - val_loss: 0.2268 - val_mean_absolute_error: 0.2268 - 474ms/epoch - 14ms/step
# Epoch 97/3000
# 33/33 - 0s - loss: 0.0896 - mean_absolute_error: 0.0896 - val_loss: 0.2202 - val_mean_absolute_error: 0.2202 - 478ms/epoch - 14ms/step
# Epoch 98/3000
# 33/33 - 0s - loss: 0.0939 - mean_absolute_error: 0.0939 - val_loss: 0.2236 - val_mean_absolute_error: 0.2236 - 470ms/epoch - 14ms/step
# Epoch 99/3000
# 33/33 - 0s - loss: 0.0896 - mean_absolute_error: 0.0896 - val_loss: 0.2291 - val_mean_absolute_error: 0.2291 - 475ms/epoch - 14ms/step
# Epoch 100/3000
# 33/33 - 0s - loss: 0.0984 - mean_absolute_error: 0.0984 - val_loss: 0.2186 - val_mean_absolute_error: 0.2186 - 478ms/epoch - 14ms/step
# Epoch 101/3000
# 33/33 - 0s - loss: 0.0904 - mean_absolute_error: 0.0904 - val_loss: 0.2137 - val_mean_absolute_error: 0.2137 - 480ms/epoch - 15ms/step
# Epoch 102/3000
# 33/33 - 0s - loss: 0.0903 - mean_absolute_error: 0.0903 - val_loss: 0.2154 - val_mean_absolute_error: 0.2154 - 474ms/epoch - 14ms/step
# Epoch 103/3000
# 33/33 - 0s - loss: 0.0877 - mean_absolute_error: 0.0877 - val_loss: 0.2230 - val_mean_absolute_error: 0.2230 - 484ms/epoch - 15ms/step
# Epoch 104/3000
# 33/33 - 1s - loss: 0.0842 - mean_absolute_error: 0.0842 - val_loss: 0.2157 - val_mean_absolute_error: 0.2157 - 551ms/epoch - 17ms/step
# Epoch 105/3000
# 33/33 - 1s - loss: 0.0997 - mean_absolute_error: 0.0997 - val_loss: 0.2342 - val_mean_absolute_error: 0.2342 - 615ms/epoch - 19ms/step
# Epoch 106/3000
# 33/33 - 1s - loss: 0.1171 - mean_absolute_error: 0.1171 - val_loss: 0.2106 - val_mean_absolute_error: 0.2106 - 528ms/epoch - 16ms/step
# Epoch 107/3000
# 33/33 - 1s - loss: 0.1022 - mean_absolute_error: 0.1022 - val_loss: 0.2028 - val_mean_absolute_error: 0.2028 - 520ms/epoch - 16ms/step
# Epoch 108/3000
# 33/33 - 1s - loss: 0.0895 - mean_absolute_error: 0.0895 - val_loss: 0.2186 - val_mean_absolute_error: 0.2186 - 524ms/epoch - 16ms/step
# Epoch 109/3000
# 33/33 - 1s - loss: 0.0872 - mean_absolute_error: 0.0872 - val_loss: 0.2285 - val_mean_absolute_error: 0.2285 - 518ms/epoch - 16ms/step
# Epoch 110/3000
# 33/33 - 0s - loss: 0.1097 - mean_absolute_error: 0.1097 - val_loss: 0.2118 - val_mean_absolute_error: 0.2118 - 493ms/epoch - 15ms/step
# Epoch 111/3000
# 33/33 - 0s - loss: 0.0969 - mean_absolute_error: 0.0969 - val_loss: 0.2339 - val_mean_absolute_error: 0.2339 - 487ms/epoch - 15ms/step
# Epoch 112/3000
# 33/33 - 0s - loss: 0.0895 - mean_absolute_error: 0.0895 - val_loss: 0.2159 - val_mean_absolute_error: 0.2159 - 479ms/epoch - 15ms/step
# Epoch 113/3000
# 33/33 - 0s - loss: 0.0920 - mean_absolute_error: 0.0920 - val_loss: 0.2214 - val_mean_absolute_error: 0.2214 - 484ms/epoch - 15ms/step
# Epoch 114/3000
# 33/33 - 0s - loss: 0.0944 - mean_absolute_error: 0.0944 - val_loss: 0.2399 - val_mean_absolute_error: 0.2399 - 496ms/epoch - 15ms/step
# Epoch 115/3000
# 33/33 - 0s - loss: 0.1011 - mean_absolute_error: 0.1011 - val_loss: 0.2250 - val_mean_absolute_error: 0.2250 - 492ms/epoch - 15ms/step
# Epoch 116/3000
# 33/33 - 0s - loss: 0.0962 - mean_absolute_error: 0.0962 - val_loss: 0.2165 - val_mean_absolute_error: 0.2165 - 480ms/epoch - 15ms/step
# Epoch 117/3000
# 33/33 - 0s - loss: 0.0835 - mean_absolute_error: 0.0835 - val_loss: 0.2169 - val_mean_absolute_error: 0.2169 - 477ms/epoch - 14ms/step
# Epoch 118/3000
# 33/33 - 0s - loss: 0.0993 - mean_absolute_error: 0.0993 - val_loss: 0.2050 - val_mean_absolute_error: 0.2050 - 492ms/epoch - 15ms/step
# Epoch 119/3000
# 33/33 - 0s - loss: 0.0847 - mean_absolute_error: 0.0847 - val_loss: 0.2084 - val_mean_absolute_error: 0.2084 - 464ms/epoch - 14ms/step
# Epoch 120/3000
# 33/33 - 0s - loss: 0.0819 - mean_absolute_error: 0.0819 - val_loss: 0.2139 - val_mean_absolute_error: 0.2139 - 482ms/epoch - 15ms/step
# Epoch 121/3000
# 33/33 - 0s - loss: 0.0813 - mean_absolute_error: 0.0813 - val_loss: 0.2243 - val_mean_absolute_error: 0.2243 - 473ms/epoch - 14ms/step
# Epoch 122/3000
# 33/33 - 1s - loss: 0.0864 - mean_absolute_error: 0.0864 - val_loss: 0.2228 - val_mean_absolute_error: 0.2228 - 522ms/epoch - 16ms/step
# Epoch 123/3000
# 33/33 - 1s - loss: 0.0810 - mean_absolute_error: 0.0810 - val_loss: 0.2149 - val_mean_absolute_error: 0.2149 - 563ms/epoch - 17ms/step
# Epoch 124/3000
# 33/33 - 1s - loss: 0.0816 - mean_absolute_error: 0.0816 - val_loss: 0.2148 - val_mean_absolute_error: 0.2148 - 556ms/epoch - 17ms/step
# Epoch 125/3000
# 33/33 - 1s - loss: 0.0851 - mean_absolute_error: 0.0851 - val_loss: 0.2353 - val_mean_absolute_error: 0.2353 - 571ms/epoch - 17ms/step
# Epoch 126/3000
# 33/33 - 1s - loss: 0.0854 - mean_absolute_error: 0.0854 - val_loss: 0.2180 - val_mean_absolute_error: 0.2180 - 578ms/epoch - 18ms/step
# Epoch 127/3000
# 33/33 - 1s - loss: 0.0834 - mean_absolute_error: 0.0834 - val_loss: 0.2467 - val_mean_absolute_error: 0.2467 - 580ms/epoch - 18ms/step
# Epoch 128/3000
# 33/33 - 1s - loss: 0.0956 - mean_absolute_error: 0.0956 - val_loss: 0.2171 - val_mean_absolute_error: 0.2171 - 570ms/epoch - 17ms/step
# Epoch 129/3000
# 33/33 - 1s - loss: 0.0841 - mean_absolute_error: 0.0841 - val_loss: 0.2116 - val_mean_absolute_error: 0.2116 - 559ms/epoch - 17ms/step
# Epoch 130/3000
# 33/33 - 1s - loss: 0.0834 - mean_absolute_error: 0.0834 - val_loss: 0.2119 - val_mean_absolute_error: 0.2119 - 585ms/epoch - 18ms/step
# Epoch 131/3000
# 33/33 - 1s - loss: 0.0794 - mean_absolute_error: 0.0794 - val_loss: 0.2087 - val_mean_absolute_error: 0.2087 - 578ms/epoch - 18ms/step
# Epoch 132/3000
# 33/33 - 1s - loss: 0.0790 - mean_absolute_error: 0.0790 - val_loss: 0.2139 - val_mean_absolute_error: 0.2139 - 564ms/epoch - 17ms/step
# Epoch 133/3000
# 33/33 - 1s - loss: 0.0768 - mean_absolute_error: 0.0768 - val_loss: 0.2132 - val_mean_absolute_error: 0.2132 - 634ms/epoch - 19ms/step
# Epoch 134/3000
# 33/33 - 1s - loss: 0.0887 - mean_absolute_error: 0.0887 - val_loss: 0.2159 - val_mean_absolute_error: 0.2159 - 616ms/epoch - 19ms/step
# Epoch 135/3000
# 33/33 - 1s - loss: 0.0931 - mean_absolute_error: 0.0931 - val_loss: 0.2173 - val_mean_absolute_error: 0.2173 - 627ms/epoch - 19ms/step
# Epoch 136/3000
# 33/33 - 1s - loss: 0.0794 - mean_absolute_error: 0.0794 - val_loss: 0.2145 - val_mean_absolute_error: 0.2145 - 582ms/epoch - 18ms/step
# Epoch 137/3000
# 33/33 - 1s - loss: 0.0795 - mean_absolute_error: 0.0795 - val_loss: 0.2246 - val_mean_absolute_error: 0.2246 - 548ms/epoch - 17ms/step
# Epoch 138/3000
# 33/33 - 1s - loss: 0.0885 - mean_absolute_error: 0.0885 - val_loss: 0.2390 - val_mean_absolute_error: 0.2390 - 557ms/epoch - 17ms/step
# Epoch 139/3000
# 33/33 - 1s - loss: 0.0876 - mean_absolute_error: 0.0876 - val_loss: 0.2116 - val_mean_absolute_error: 0.2116 - 565ms/epoch - 17ms/step
# Epoch 140/3000
# 33/33 - 1s - loss: 0.0815 - mean_absolute_error: 0.0815 - val_loss: 0.2115 - val_mean_absolute_error: 0.2115 - 557ms/epoch - 17ms/step
# Epoch 141/3000
# 33/33 - 1s - loss: 0.0871 - mean_absolute_error: 0.0871 - val_loss: 0.2102 - val_mean_absolute_error: 0.2102 - 706ms/epoch - 21ms/step
# Epoch 142/3000
# 33/33 - 1s - loss: 0.0851 - mean_absolute_error: 0.0851 - val_loss: 0.2035 - val_mean_absolute_error: 0.2035 - 565ms/epoch - 17ms/step
# Epoch 143/3000
# 33/33 - 1s - loss: 0.0802 - mean_absolute_error: 0.0802 - val_loss: 0.2138 - val_mean_absolute_error: 0.2138 - 552ms/epoch - 17ms/step
# Epoch 144/3000
# 33/33 - 1s - loss: 0.0812 - mean_absolute_error: 0.0812 - val_loss: 0.2158 - val_mean_absolute_error: 0.2158 - 560ms/epoch - 17ms/step
# Epoch 145/3000
# 33/33 - 1s - loss: 0.0936 - mean_absolute_error: 0.0936 - val_loss: 0.2097 - val_mean_absolute_error: 0.2097 - 549ms/epoch - 17ms/step
# Epoch 146/3000
# 33/33 - 1s - loss: 0.0779 - mean_absolute_error: 0.0779 - val_loss: 0.2253 - val_mean_absolute_error: 0.2253 - 549ms/epoch - 17ms/step
# Epoch 147/3000
# 33/33 - 1s - loss: 0.0817 - mean_absolute_error: 0.0817 - val_loss: 0.1971 - val_mean_absolute_error: 0.1971 - 553ms/epoch - 17ms/step
# Epoch 148/3000
# 33/33 - 1s - loss: 0.0798 - mean_absolute_error: 0.0798 - val_loss: 0.2253 - val_mean_absolute_error: 0.2253 - 562ms/epoch - 17ms/step
# Epoch 149/3000
# 33/33 - 1s - loss: 0.0920 - mean_absolute_error: 0.0920 - val_loss: 0.2034 - val_mean_absolute_error: 0.2034 - 546ms/epoch - 17ms/step
# Epoch 150/3000
# 33/33 - 1s - loss: 0.0783 - mean_absolute_error: 0.0783 - val_loss: 0.2101 - val_mean_absolute_error: 0.2101 - 557ms/epoch - 17ms/step
# Epoch 151/3000
# 33/33 - 1s - loss: 0.0815 - mean_absolute_error: 0.0815 - val_loss: 0.2099 - val_mean_absolute_error: 0.2099 - 547ms/epoch - 17ms/step
# Epoch 152/3000
# 33/33 - 1s - loss: 0.0865 - mean_absolute_error: 0.0865 - val_loss: 0.2067 - val_mean_absolute_error: 0.2067 - 580ms/epoch - 18ms/step
# Epoch 153/3000
# 33/33 - 1s - loss: 0.0813 - mean_absolute_error: 0.0813 - val_loss: 0.2138 - val_mean_absolute_error: 0.2138 - 582ms/epoch - 18ms/step
# Epoch 154/3000
# 33/33 - 1s - loss: 0.0819 - mean_absolute_error: 0.0819 - val_loss: 0.2034 - val_mean_absolute_error: 0.2034 - 589ms/epoch - 18ms/step
# Epoch 155/3000
# 33/33 - 1s - loss: 0.0836 - mean_absolute_error: 0.0836 - val_loss: 0.2131 - val_mean_absolute_error: 0.2131 - 560ms/epoch - 17ms/step
# Epoch 156/3000
# 33/33 - 1s - loss: 0.0861 - mean_absolute_error: 0.0861 - val_loss: 0.2130 - val_mean_absolute_error: 0.2130 - 560ms/epoch - 17ms/step
# Epoch 157/3000
# 33/33 - 1s - loss: 0.0923 - mean_absolute_error: 0.0923 - val_loss: 0.2136 - val_mean_absolute_error: 0.2136 - 598ms/epoch - 18ms/step
# Epoch 158/3000
# 33/33 - 1s - loss: 0.0830 - mean_absolute_error: 0.0830 - val_loss: 0.2203 - val_mean_absolute_error: 0.2203 - 526ms/epoch - 16ms/step
# Epoch 159/3000
# 33/33 - 1s - loss: 0.0808 - mean_absolute_error: 0.0808 - val_loss: 0.2002 - val_mean_absolute_error: 0.2002 - 519ms/epoch - 16ms/step
# Epoch 160/3000
# 33/33 - 1s - loss: 0.0752 - mean_absolute_error: 0.0752 - val_loss: 0.2046 - val_mean_absolute_error: 0.2046 - 529ms/epoch - 16ms/step
# Epoch 161/3000
# 33/33 - 1s - loss: 0.0805 - mean_absolute_error: 0.0805 - val_loss: 0.2156 - val_mean_absolute_error: 0.2156 - 539ms/epoch - 16ms/step
# Epoch 162/3000
# 33/33 - 1s - loss: 0.0773 - mean_absolute_error: 0.0773 - val_loss: 0.2054 - val_mean_absolute_error: 0.2054 - 556ms/epoch - 17ms/step
# Epoch 163/3000
# 33/33 - 1s - loss: 0.0793 - mean_absolute_error: 0.0793 - val_loss: 0.2186 - val_mean_absolute_error: 0.2186 - 694ms/epoch - 21ms/step
# Epoch 164/3000
# 33/33 - 1s - loss: 0.0928 - mean_absolute_error: 0.0928 - val_loss: 0.2031 - val_mean_absolute_error: 0.2031 - 559ms/epoch - 17ms/step
# Epoch 165/3000
# 33/33 - 1s - loss: 0.0804 - mean_absolute_error: 0.0804 - val_loss: 0.2241 - val_mean_absolute_error: 0.2241 - 555ms/epoch - 17ms/step
# Epoch 166/3000
# 33/33 - 1s - loss: 0.0808 - mean_absolute_error: 0.0808 - val_loss: 0.2054 - val_mean_absolute_error: 0.2054 - 519ms/epoch - 16ms/step
# Epoch 167/3000
# 33/33 - 1s - loss: 0.0736 - mean_absolute_error: 0.0736 - val_loss: 0.1989 - val_mean_absolute_error: 0.1989 - 531ms/epoch - 16ms/step
# Epoch 168/3000
# 33/33 - 1s - loss: 0.0827 - mean_absolute_error: 0.0827 - val_loss: 0.2172 - val_mean_absolute_error: 0.2172 - 538ms/epoch - 16ms/step
# Epoch 169/3000
# 33/33 - 1s - loss: 0.0858 - mean_absolute_error: 0.0858 - val_loss: 0.2084 - val_mean_absolute_error: 0.2084 - 522ms/epoch - 16ms/step
# Epoch 170/3000
# 33/33 - 1s - loss: 0.0691 - mean_absolute_error: 0.0691 - val_loss: 0.2001 - val_mean_absolute_error: 0.2001 - 552ms/epoch - 17ms/step
# Epoch 171/3000
# 33/33 - 1s - loss: 0.0717 - mean_absolute_error: 0.0717 - val_loss: 0.1951 - val_mean_absolute_error: 0.1951 - 542ms/epoch - 16ms/step
# Epoch 172/3000
# 33/33 - 1s - loss: 0.0807 - mean_absolute_error: 0.0807 - val_loss: 0.2101 - val_mean_absolute_error: 0.2101 - 635ms/epoch - 19ms/step
# Epoch 173/3000
# 33/33 - 1s - loss: 0.0799 - mean_absolute_error: 0.0799 - val_loss: 0.2036 - val_mean_absolute_error: 0.2036 - 574ms/epoch - 17ms/step
# Epoch 174/3000
# 33/33 - 1s - loss: 0.0709 - mean_absolute_error: 0.0709 - val_loss: 0.2010 - val_mean_absolute_error: 0.2010 - 516ms/epoch - 16ms/step
# Epoch 175/3000
# 33/33 - 1s - loss: 0.0795 - mean_absolute_error: 0.0795 - val_loss: 0.2173 - val_mean_absolute_error: 0.2173 - 526ms/epoch - 16ms/step
# Epoch 176/3000
# 33/33 - 1s - loss: 0.0748 - mean_absolute_error: 0.0748 - val_loss: 0.2005 - val_mean_absolute_error: 0.2005 - 537ms/epoch - 16ms/step
# Epoch 177/3000
# 33/33 - 1s - loss: 0.0743 - mean_absolute_error: 0.0743 - val_loss: 0.1945 - val_mean_absolute_error: 0.1945 - 506ms/epoch - 15ms/step
# Epoch 178/3000
# 33/33 - 1s - loss: 0.0817 - mean_absolute_error: 0.0817 - val_loss: 0.2162 - val_mean_absolute_error: 0.2162 - 508ms/epoch - 15ms/step
# Epoch 179/3000
# 33/33 - 1s - loss: 0.0859 - mean_absolute_error: 0.0859 - val_loss: 0.2039 - val_mean_absolute_error: 0.2039 - 523ms/epoch - 16ms/step
# Epoch 180/3000
# 33/33 - 1s - loss: 0.0737 - mean_absolute_error: 0.0737 - val_loss: 0.2188 - val_mean_absolute_error: 0.2188 - 523ms/epoch - 16ms/step
# Epoch 181/3000
# 33/33 - 1s - loss: 0.0789 - mean_absolute_error: 0.0789 - val_loss: 0.2033 - val_mean_absolute_error: 0.2033 - 512ms/epoch - 16ms/step
# Epoch 182/3000
# 33/33 - 1s - loss: 0.0703 - mean_absolute_error: 0.0703 - val_loss: 0.1997 - val_mean_absolute_error: 0.1997 - 507ms/epoch - 15ms/step
# Epoch 183/3000
# 33/33 - 1s - loss: 0.0700 - mean_absolute_error: 0.0700 - val_loss: 0.1959 - val_mean_absolute_error: 0.1959 - 518ms/epoch - 16ms/step
# Epoch 184/3000
# 33/33 - 1s - loss: 0.0729 - mean_absolute_error: 0.0729 - val_loss: 0.2020 - val_mean_absolute_error: 0.2020 - 519ms/epoch - 16ms/step
# Epoch 185/3000
# 33/33 - 1s - loss: 0.0739 - mean_absolute_error: 0.0739 - val_loss: 0.2046 - val_mean_absolute_error: 0.2046 - 508ms/epoch - 15ms/step
# Epoch 186/3000
# 33/33 - 1s - loss: 0.0754 - mean_absolute_error: 0.0754 - val_loss: 0.1875 - val_mean_absolute_error: 0.1875 - 519ms/epoch - 16ms/step
# Epoch 187/3000
# 33/33 - 1s - loss: 0.0801 - mean_absolute_error: 0.0801 - val_loss: 0.2120 - val_mean_absolute_error: 0.2120 - 511ms/epoch - 15ms/step
# Epoch 188/3000
# 33/33 - 1s - loss: 0.0752 - mean_absolute_error: 0.0752 - val_loss: 0.2094 - val_mean_absolute_error: 0.2094 - 513ms/epoch - 16ms/step
# Epoch 189/3000
# 33/33 - 0s - loss: 0.0836 - mean_absolute_error: 0.0836 - val_loss: 0.2048 - val_mean_absolute_error: 0.2048 - 494ms/epoch - 15ms/step
# Epoch 190/3000
# 33/33 - 0s - loss: 0.0708 - mean_absolute_error: 0.0708 - val_loss: 0.2005 - val_mean_absolute_error: 0.2005 - 496ms/epoch - 15ms/step
# Epoch 191/3000
# 33/33 - 1s - loss: 0.0700 - mean_absolute_error: 0.0700 - val_loss: 0.1960 - val_mean_absolute_error: 0.1960 - 507ms/epoch - 15ms/step
# Epoch 192/3000
# 33/33 - 1s - loss: 0.0758 - mean_absolute_error: 0.0758 - val_loss: 0.2043 - val_mean_absolute_error: 0.2043 - 504ms/epoch - 15ms/step
# Epoch 193/3000
# 33/33 - 1s - loss: 0.0859 - mean_absolute_error: 0.0859 - val_loss: 0.2066 - val_mean_absolute_error: 0.2066 - 507ms/epoch - 15ms/step
# Epoch 194/3000
# 33/33 - 0s - loss: 0.0698 - mean_absolute_error: 0.0698 - val_loss: 0.2000 - val_mean_absolute_error: 0.2000 - 498ms/epoch - 15ms/step
# Epoch 195/3000
# 33/33 - 1s - loss: 0.0725 - mean_absolute_error: 0.0725 - val_loss: 0.2003 - val_mean_absolute_error: 0.2003 - 506ms/epoch - 15ms/step
# Epoch 196/3000
# 33/33 - 1s - loss: 0.0762 - mean_absolute_error: 0.0762 - val_loss: 0.2146 - val_mean_absolute_error: 0.2146 - 511ms/epoch - 15ms/step
# Epoch 197/3000
# 33/33 - 1s - loss: 0.0742 - mean_absolute_error: 0.0742 - val_loss: 0.1905 - val_mean_absolute_error: 0.1905 - 537ms/epoch - 16ms/step
# Epoch 198/3000
# 33/33 - 1s - loss: 0.0726 - mean_absolute_error: 0.0726 - val_loss: 0.1945 - val_mean_absolute_error: 0.1945 - 570ms/epoch - 17ms/step
# Epoch 199/3000
# 33/33 - 1s - loss: 0.0737 - mean_absolute_error: 0.0737 - val_loss: 0.1884 - val_mean_absolute_error: 0.1884 - 537ms/epoch - 16ms/step
# Epoch 200/3000
# 33/33 - 1s - loss: 0.0674 - mean_absolute_error: 0.0674 - val_loss: 0.1946 - val_mean_absolute_error: 0.1946 - 525ms/epoch - 16ms/step
# Epoch 201/3000
# 33/33 - 1s - loss: 0.0713 - mean_absolute_error: 0.0713 - val_loss: 0.1933 - val_mean_absolute_error: 0.1933 - 516ms/epoch - 16ms/step
# Epoch 202/3000
# 33/33 - 1s - loss: 0.0755 - mean_absolute_error: 0.0755 - val_loss: 0.1861 - val_mean_absolute_error: 0.1861 - 512ms/epoch - 16ms/step
# Epoch 203/3000
# 33/33 - 1s - loss: 0.0701 - mean_absolute_error: 0.0701 - val_loss: 0.2040 - val_mean_absolute_error: 0.2040 - 520ms/epoch - 16ms/step
# Epoch 204/3000
# 33/33 - 1s - loss: 0.0704 - mean_absolute_error: 0.0704 - val_loss: 0.1990 - val_mean_absolute_error: 0.1990 - 522ms/epoch - 16ms/step
# Epoch 205/3000
# 33/33 - 1s - loss: 0.0815 - mean_absolute_error: 0.0815 - val_loss: 0.2013 - val_mean_absolute_error: 0.2013 - 522ms/epoch - 16ms/step
# Epoch 206/3000
# 33/33 - 1s - loss: 0.0858 - mean_absolute_error: 0.0858 - val_loss: 0.2028 - val_mean_absolute_error: 0.2028 - 505ms/epoch - 15ms/step
# Epoch 207/3000
# 33/33 - 1s - loss: 0.0762 - mean_absolute_error: 0.0762 - val_loss: 0.1999 - val_mean_absolute_error: 0.1999 - 510ms/epoch - 15ms/step
# Epoch 208/3000
# 33/33 - 1s - loss: 0.0730 - mean_absolute_error: 0.0730 - val_loss: 0.2137 - val_mean_absolute_error: 0.2137 - 513ms/epoch - 16ms/step
# Epoch 209/3000
# 33/33 - 1s - loss: 0.0714 - mean_absolute_error: 0.0714 - val_loss: 0.1958 - val_mean_absolute_error: 0.1958 - 513ms/epoch - 16ms/step
# Epoch 210/3000
# 33/33 - 0s - loss: 0.0695 - mean_absolute_error: 0.0695 - val_loss: 0.1958 - val_mean_absolute_error: 0.1958 - 488ms/epoch - 15ms/step
# Epoch 211/3000
# 33/33 - 1s - loss: 0.0710 - mean_absolute_error: 0.0710 - val_loss: 0.1914 - val_mean_absolute_error: 0.1914 - 513ms/epoch - 16ms/step
# Epoch 212/3000
# 33/33 - 0s - loss: 0.0734 - mean_absolute_error: 0.0734 - val_loss: 0.2059 - val_mean_absolute_error: 0.2059 - 490ms/epoch - 15ms/step
# Epoch 213/3000
# 33/33 - 1s - loss: 0.0754 - mean_absolute_error: 0.0754 - val_loss: 0.2008 - val_mean_absolute_error: 0.2008 - 518ms/epoch - 16ms/step
# Epoch 214/3000
# 33/33 - 0s - loss: 0.0736 - mean_absolute_error: 0.0736 - val_loss: 0.2173 - val_mean_absolute_error: 0.2173 - 500ms/epoch - 15ms/step
# Epoch 215/3000
# 33/33 - 0s - loss: 0.0769 - mean_absolute_error: 0.0769 - val_loss: 0.2320 - val_mean_absolute_error: 0.2320 - 485ms/epoch - 15ms/step
# Epoch 216/3000
# 33/33 - 0s - loss: 0.0737 - mean_absolute_error: 0.0737 - val_loss: 0.2003 - val_mean_absolute_error: 0.2003 - 489ms/epoch - 15ms/step
# Epoch 217/3000
# 33/33 - 1s - loss: 0.0676 - mean_absolute_error: 0.0676 - val_loss: 0.2028 - val_mean_absolute_error: 0.2028 - 511ms/epoch - 15ms/step
# Epoch 218/3000
# 33/33 - 1s - loss: 0.0719 - mean_absolute_error: 0.0719 - val_loss: 0.2058 - val_mean_absolute_error: 0.2058 - 514ms/epoch - 16ms/step
# Epoch 219/3000
# 33/33 - 0s - loss: 0.0671 - mean_absolute_error: 0.0671 - val_loss: 0.2000 - val_mean_absolute_error: 0.2000 - 487ms/epoch - 15ms/step
# Epoch 220/3000
# 33/33 - 1s - loss: 0.0634 - mean_absolute_error: 0.0634 - val_loss: 0.2042 - val_mean_absolute_error: 0.2042 - 500ms/epoch - 15ms/step
# Epoch 221/3000
# 33/33 - 1s - loss: 0.0698 - mean_absolute_error: 0.0698 - val_loss: 0.2255 - val_mean_absolute_error: 0.2255 - 502ms/epoch - 15ms/step
# Epoch 222/3000
# 33/33 - 1s - loss: 0.0834 - mean_absolute_error: 0.0834 - val_loss: 0.2003 - val_mean_absolute_error: 0.2003 - 504ms/epoch - 15ms/step
# Epoch 223/3000
# 33/33 - 0s - loss: 0.0702 - mean_absolute_error: 0.0702 - val_loss: 0.1985 - val_mean_absolute_error: 0.1985 - 500ms/epoch - 15ms/step
# Epoch 224/3000
# 33/33 - 0s - loss: 0.0724 - mean_absolute_error: 0.0724 - val_loss: 0.1944 - val_mean_absolute_error: 0.1944 - 495ms/epoch - 15ms/step
# Epoch 225/3000
# 33/33 - 0s - loss: 0.0694 - mean_absolute_error: 0.0694 - val_loss: 0.2065 - val_mean_absolute_error: 0.2065 - 499ms/epoch - 15ms/step
# Epoch 226/3000
# 33/33 - 0s - loss: 0.0715 - mean_absolute_error: 0.0715 - val_loss: 0.1994 - val_mean_absolute_error: 0.1994 - 489ms/epoch - 15ms/step
# Epoch 227/3000
# 33/33 - 0s - loss: 0.0609 - mean_absolute_error: 0.0609 - val_loss: 0.2001 - val_mean_absolute_error: 0.2001 - 486ms/epoch - 15ms/step
# Epoch 228/3000
# 33/33 - 0s - loss: 0.0661 - mean_absolute_error: 0.0661 - val_loss: 0.2015 - val_mean_absolute_error: 0.2015 - 487ms/epoch - 15ms/step
# Epoch 229/3000
# 33/33 - 0s - loss: 0.0816 - mean_absolute_error: 0.0816 - val_loss: 0.1958 - val_mean_absolute_error: 0.1958 - 489ms/epoch - 15ms/step
# Epoch 230/3000
# 33/33 - 1s - loss: 0.0709 - mean_absolute_error: 0.0709 - val_loss: 0.1904 - val_mean_absolute_error: 0.1904 - 544ms/epoch - 16ms/step
# Epoch 231/3000
# 33/33 - 1s - loss: 0.0645 - mean_absolute_error: 0.0645 - val_loss: 0.1867 - val_mean_absolute_error: 0.1867 - 502ms/epoch - 15ms/step
# Epoch 232/3000
# 33/33 - 1s - loss: 0.0685 - mean_absolute_error: 0.0685 - val_loss: 0.1991 - val_mean_absolute_error: 0.1991 - 533ms/epoch - 16ms/step
# Epoch 233/3000
# 33/33 - 1s - loss: 0.0679 - mean_absolute_error: 0.0679 - val_loss: 0.2038 - val_mean_absolute_error: 0.2038 - 544ms/epoch - 16ms/step
# Epoch 234/3000
# 33/33 - 1s - loss: 0.0642 - mean_absolute_error: 0.0642 - val_loss: 0.1975 - val_mean_absolute_error: 0.1975 - 520ms/epoch - 16ms/step
# Epoch 235/3000
# 33/33 - 1s - loss: 0.0749 - mean_absolute_error: 0.0749 - val_loss: 0.2267 - val_mean_absolute_error: 0.2267 - 508ms/epoch - 15ms/step
# Epoch 236/3000
# 33/33 - 0s - loss: 0.0721 - mean_absolute_error: 0.0721 - val_loss: 0.1944 - val_mean_absolute_error: 0.1944 - 491ms/epoch - 15ms/step
# Epoch 237/3000
# 33/33 - 0s - loss: 0.0778 - mean_absolute_error: 0.0778 - val_loss: 0.1871 - val_mean_absolute_error: 0.1871 - 492ms/epoch - 15ms/step
# Epoch 238/3000
# 33/33 - 1s - loss: 0.0673 - mean_absolute_error: 0.0673 - val_loss: 0.1938 - val_mean_absolute_error: 0.1938 - 514ms/epoch - 16ms/step
# Epoch 239/3000
# 33/33 - 1s - loss: 0.0677 - mean_absolute_error: 0.0677 - val_loss: 0.2146 - val_mean_absolute_error: 0.2146 - 504ms/epoch - 15ms/step
# Epoch 240/3000
# 33/33 - 0s - loss: 0.0707 - mean_absolute_error: 0.0707 - val_loss: 0.1934 - val_mean_absolute_error: 0.1934 - 478ms/epoch - 14ms/step
# Epoch 241/3000
# 33/33 - 0s - loss: 0.0625 - mean_absolute_error: 0.0625 - val_loss: 0.2020 - val_mean_absolute_error: 0.2020 - 484ms/epoch - 15ms/step
# Epoch 242/3000
# 33/33 - 0s - loss: 0.0661 - mean_absolute_error: 0.0661 - val_loss: 0.1877 - val_mean_absolute_error: 0.1877 - 485ms/epoch - 15ms/step
# Epoch 243/3000
# 33/33 - 0s - loss: 0.0742 - mean_absolute_error: 0.0742 - val_loss: 0.1955 - val_mean_absolute_error: 0.1955 - 486ms/epoch - 15ms/step
# Epoch 244/3000
# 33/33 - 0s - loss: 0.0727 - mean_absolute_error: 0.0727 - val_loss: 0.2028 - val_mean_absolute_error: 0.2028 - 485ms/epoch - 15ms/step
# Epoch 245/3000
# 33/33 - 0s - loss: 0.0664 - mean_absolute_error: 0.0664 - val_loss: 0.1871 - val_mean_absolute_error: 0.1871 - 487ms/epoch - 15ms/step
# Epoch 246/3000
# 33/33 - 0s - loss: 0.0629 - mean_absolute_error: 0.0629 - val_loss: 0.1878 - val_mean_absolute_error: 0.1878 - 486ms/epoch - 15ms/step
# Epoch 247/3000
# 33/33 - 0s - loss: 0.0676 - mean_absolute_error: 0.0676 - val_loss: 0.2001 - val_mean_absolute_error: 0.2001 - 495ms/epoch - 15ms/step
# Epoch 248/3000
# 33/33 - 0s - loss: 0.0695 - mean_absolute_error: 0.0695 - val_loss: 0.1914 - val_mean_absolute_error: 0.1914 - 485ms/epoch - 15ms/step
# Epoch 249/3000
# 33/33 - 0s - loss: 0.0653 - mean_absolute_error: 0.0653 - val_loss: 0.1885 - val_mean_absolute_error: 0.1885 - 488ms/epoch - 15ms/step
# Epoch 250/3000
# 33/33 - 0s - loss: 0.0635 - mean_absolute_error: 0.0635 - val_loss: 0.1848 - val_mean_absolute_error: 0.1848 - 493ms/epoch - 15ms/step
# Epoch 251/3000
# 33/33 - 0s - loss: 0.0700 - mean_absolute_error: 0.0700 - val_loss: 0.1843 - val_mean_absolute_error: 0.1843 - 492ms/epoch - 15ms/step
# Epoch 252/3000
# 33/33 - 1s - loss: 0.0641 - mean_absolute_error: 0.0641 - val_loss: 0.1952 - val_mean_absolute_error: 0.1952 - 502ms/epoch - 15ms/step
# Epoch 253/3000
# 33/33 - 0s - loss: 0.0633 - mean_absolute_error: 0.0633 - val_loss: 0.1885 - val_mean_absolute_error: 0.1885 - 491ms/epoch - 15ms/step
# Epoch 254/3000
# 33/33 - 0s - loss: 0.0632 - mean_absolute_error: 0.0632 - val_loss: 0.1917 - val_mean_absolute_error: 0.1917 - 463ms/epoch - 14ms/step
# Epoch 255/3000
# 33/33 - 1s - loss: 0.0608 - mean_absolute_error: 0.0608 - val_loss: 0.1925 - val_mean_absolute_error: 0.1925 - 543ms/epoch - 16ms/step
# Epoch 256/3000
# 33/33 - 0s - loss: 0.0601 - mean_absolute_error: 0.0601 - val_loss: 0.2027 - val_mean_absolute_error: 0.2027 - 461ms/epoch - 14ms/step
# Epoch 257/3000
# 33/33 - 0s - loss: 0.0655 - mean_absolute_error: 0.0655 - val_loss: 0.1965 - val_mean_absolute_error: 0.1965 - 478ms/epoch - 14ms/step
# Epoch 258/3000
# 33/33 - 0s - loss: 0.0649 - mean_absolute_error: 0.0649 - val_loss: 0.2038 - val_mean_absolute_error: 0.2038 - 476ms/epoch - 14ms/step
# Epoch 259/3000
# 33/33 - 0s - loss: 0.0791 - mean_absolute_error: 0.0791 - val_loss: 0.1932 - val_mean_absolute_error: 0.1932 - 470ms/epoch - 14ms/step
# Epoch 260/3000
# 33/33 - 0s - loss: 0.0644 - mean_absolute_error: 0.0644 - val_loss: 0.2158 - val_mean_absolute_error: 0.2158 - 486ms/epoch - 15ms/step
# Epoch 261/3000
# 33/33 - 0s - loss: 0.0719 - mean_absolute_error: 0.0719 - val_loss: 0.1915 - val_mean_absolute_error: 0.1915 - 469ms/epoch - 14ms/step
# Epoch 262/3000
# 33/33 - 0s - loss: 0.0624 - mean_absolute_error: 0.0624 - val_loss: 0.1922 - val_mean_absolute_error: 0.1922 - 470ms/epoch - 14ms/step
# Epoch 263/3000
# 33/33 - 0s - loss: 0.0656 - mean_absolute_error: 0.0656 - val_loss: 0.2067 - val_mean_absolute_error: 0.2067 - 468ms/epoch - 14ms/step
# Epoch 264/3000
# 33/33 - 0s - loss: 0.0667 - mean_absolute_error: 0.0667 - val_loss: 0.1921 - val_mean_absolute_error: 0.1921 - 476ms/epoch - 14ms/step
# Epoch 265/3000
# 33/33 - 0s - loss: 0.0652 - mean_absolute_error: 0.0652 - val_loss: 0.1944 - val_mean_absolute_error: 0.1944 - 472ms/epoch - 14ms/step
# Epoch 266/3000
# 33/33 - 0s - loss: 0.0606 - mean_absolute_error: 0.0606 - val_loss: 0.2016 - val_mean_absolute_error: 0.2016 - 478ms/epoch - 14ms/step
# Epoch 267/3000
# 33/33 - 0s - loss: 0.0596 - mean_absolute_error: 0.0596 - val_loss: 0.1904 - val_mean_absolute_error: 0.1904 - 482ms/epoch - 15ms/step
# Epoch 268/3000
# 33/33 - 0s - loss: 0.0598 - mean_absolute_error: 0.0598 - val_loss: 0.1880 - val_mean_absolute_error: 0.1880 - 466ms/epoch - 14ms/step
# Epoch 269/3000
# 33/33 - 0s - loss: 0.0629 - mean_absolute_error: 0.0629 - val_loss: 0.2051 - val_mean_absolute_error: 0.2051 - 474ms/epoch - 14ms/step
# Epoch 270/3000
# 33/33 - 0s - loss: 0.0606 - mean_absolute_error: 0.0606 - val_loss: 0.1988 - val_mean_absolute_error: 0.1988 - 491ms/epoch - 15ms/step
# Epoch 271/3000
# 33/33 - 0s - loss: 0.0720 - mean_absolute_error: 0.0720 - val_loss: 0.1937 - val_mean_absolute_error: 0.1937 - 500ms/epoch - 15ms/step
# Epoch 272/3000
# 33/33 - 0s - loss: 0.0584 - mean_absolute_error: 0.0584 - val_loss: 0.1889 - val_mean_absolute_error: 0.1889 - 498ms/epoch - 15ms/step
# Epoch 273/3000
# 33/33 - 0s - loss: 0.0635 - mean_absolute_error: 0.0635 - val_loss: 0.1872 - val_mean_absolute_error: 0.1872 - 491ms/epoch - 15ms/step
# Epoch 274/3000
# 33/33 - 1s - loss: 0.0645 - mean_absolute_error: 0.0645 - val_loss: 0.1900 - val_mean_absolute_error: 0.1900 - 517ms/epoch - 16ms/step
# Epoch 275/3000
# 33/33 - 0s - loss: 0.0650 - mean_absolute_error: 0.0650 - val_loss: 0.1890 - val_mean_absolute_error: 0.1890 - 498ms/epoch - 15ms/step
# Epoch 276/3000
# 33/33 - 1s - loss: 0.0677 - mean_absolute_error: 0.0677 - val_loss: 0.1922 - val_mean_absolute_error: 0.1922 - 502ms/epoch - 15ms/step
# Epoch 277/3000
# 33/33 - 1s - loss: 0.0659 - mean_absolute_error: 0.0659 - val_loss: 0.1877 - val_mean_absolute_error: 0.1877 - 501ms/epoch - 15ms/step
# Epoch 278/3000
# 33/33 - 0s - loss: 0.0598 - mean_absolute_error: 0.0598 - val_loss: 0.2045 - val_mean_absolute_error: 0.2045 - 480ms/epoch - 15ms/step
# Epoch 279/3000
# 33/33 - 0s - loss: 0.0597 - mean_absolute_error: 0.0597 - val_loss: 0.1886 - val_mean_absolute_error: 0.1886 - 487ms/epoch - 15ms/step
# Epoch 280/3000
# 33/33 - 0s - loss: 0.0657 - mean_absolute_error: 0.0657 - val_loss: 0.1917 - val_mean_absolute_error: 0.1917 - 496ms/epoch - 15ms/step
# Epoch 281/3000
# 33/33 - 1s - loss: 0.0673 - mean_absolute_error: 0.0673 - val_loss: 0.2012 - val_mean_absolute_error: 0.2012 - 515ms/epoch - 16ms/step
# Epoch 282/3000
# 33/33 - 1s - loss: 0.0633 - mean_absolute_error: 0.0633 - val_loss: 0.1914 - val_mean_absolute_error: 0.1914 - 522ms/epoch - 16ms/step
# Epoch 283/3000
# 33/33 - 1s - loss: 0.0627 - mean_absolute_error: 0.0627 - val_loss: 0.1932 - val_mean_absolute_error: 0.1932 - 526ms/epoch - 16ms/step
# Epoch 284/3000
# 33/33 - 1s - loss: 0.0590 - mean_absolute_error: 0.0590 - val_loss: 0.1936 - val_mean_absolute_error: 0.1936 - 515ms/epoch - 16ms/step
# Epoch 285/3000
# 33/33 - 1s - loss: 0.0657 - mean_absolute_error: 0.0657 - val_loss: 0.1975 - val_mean_absolute_error: 0.1975 - 534ms/epoch - 16ms/step
# Epoch 286/3000
# 33/33 - 1s - loss: 0.0620 - mean_absolute_error: 0.0620 - val_loss: 0.1908 - val_mean_absolute_error: 0.1908 - 511ms/epoch - 15ms/step
# Epoch 287/3000
# 33/33 - 1s - loss: 0.0648 - mean_absolute_error: 0.0648 - val_loss: 0.1885 - val_mean_absolute_error: 0.1885 - 520ms/epoch - 16ms/step
# Epoch 288/3000
# 33/33 - 1s - loss: 0.0684 - mean_absolute_error: 0.0684 - val_loss: 0.1919 - val_mean_absolute_error: 0.1919 - 528ms/epoch - 16ms/step
# Epoch 289/3000
# 33/33 - 1s - loss: 0.0684 - mean_absolute_error: 0.0684 - val_loss: 0.1928 - val_mean_absolute_error: 0.1928 - 536ms/epoch - 16ms/step
# Epoch 290/3000
# 33/33 - 1s - loss: 0.0633 - mean_absolute_error: 0.0633 - val_loss: 0.1879 - val_mean_absolute_error: 0.1879 - 555ms/epoch - 17ms/step
# Epoch 291/3000
# 33/33 - 1s - loss: 0.0604 - mean_absolute_error: 0.0604 - val_loss: 0.1863 - val_mean_absolute_error: 0.1863 - 540ms/epoch - 16ms/step
# Epoch 292/3000
# 33/33 - 1s - loss: 0.0575 - mean_absolute_error: 0.0575 - val_loss: 0.1927 - val_mean_absolute_error: 0.1927 - 518ms/epoch - 16ms/step
# Epoch 293/3000
# 33/33 - 1s - loss: 0.0592 - mean_absolute_error: 0.0592 - val_loss: 0.1985 - val_mean_absolute_error: 0.1985 - 543ms/epoch - 16ms/step
# Epoch 294/3000
# 33/33 - 1s - loss: 0.0578 - mean_absolute_error: 0.0578 - val_loss: 0.1877 - val_mean_absolute_error: 0.1877 - 531ms/epoch - 16ms/step
# Epoch 295/3000
# 33/33 - 1s - loss: 0.0570 - mean_absolute_error: 0.0570 - val_loss: 0.1947 - val_mean_absolute_error: 0.1947 - 524ms/epoch - 16ms/step
# Epoch 296/3000
# 33/33 - 1s - loss: 0.0666 - mean_absolute_error: 0.0666 - val_loss: 0.2035 - val_mean_absolute_error: 0.2035 - 512ms/epoch - 16ms/step
# Epoch 297/3000
# 33/33 - 1s - loss: 0.0659 - mean_absolute_error: 0.0659 - val_loss: 0.1957 - val_mean_absolute_error: 0.1957 - 523ms/epoch - 16ms/step
# Epoch 298/3000
# 33/33 - 1s - loss: 0.0592 - mean_absolute_error: 0.0592 - val_loss: 0.1926 - val_mean_absolute_error: 0.1926 - 522ms/epoch - 16ms/step
# Epoch 299/3000
# 33/33 - 1s - loss: 0.0620 - mean_absolute_error: 0.0620 - val_loss: 0.1902 - val_mean_absolute_error: 0.1902 - 516ms/epoch - 16ms/step
# Epoch 300/3000
# 33/33 - 1s - loss: 0.0657 - mean_absolute_error: 0.0657 - val_loss: 0.1910 - val_mean_absolute_error: 0.1910 - 523ms/epoch - 16ms/step
# Epoch 301/3000
# 33/33 - 1s - loss: 0.0576 - mean_absolute_error: 0.0576 - val_loss: 0.1845 - val_mean_absolute_error: 0.1845 - 518ms/epoch - 16ms/step
# Epoch 302/3000
# 33/33 - 1s - loss: 0.0633 - mean_absolute_error: 0.0633 - val_loss: 0.1864 - val_mean_absolute_error: 0.1864 - 511ms/epoch - 15ms/step
# Epoch 303/3000
# 33/33 - 1s - loss: 0.0598 - mean_absolute_error: 0.0598 - val_loss: 0.1832 - val_mean_absolute_error: 0.1832 - 534ms/epoch - 16ms/step
# Epoch 304/3000
# 33/33 - 1s - loss: 0.0567 - mean_absolute_error: 0.0567 - val_loss: 0.1862 - val_mean_absolute_error: 0.1862 - 505ms/epoch - 15ms/step
# Epoch 305/3000
# 33/33 - 1s - loss: 0.0601 - mean_absolute_error: 0.0601 - val_loss: 0.1815 - val_mean_absolute_error: 0.1815 - 540ms/epoch - 16ms/step
# Epoch 306/3000
# 33/33 - 1s - loss: 0.0606 - mean_absolute_error: 0.0606 - val_loss: 0.1785 - val_mean_absolute_error: 0.1785 - 519ms/epoch - 16ms/step
# Epoch 307/3000
# 33/33 - 1s - loss: 0.0543 - mean_absolute_error: 0.0543 - val_loss: 0.1852 - val_mean_absolute_error: 0.1852 - 515ms/epoch - 16ms/step
# Epoch 308/3000
# 33/33 - 1s - loss: 0.0556 - mean_absolute_error: 0.0556 - val_loss: 0.2094 - val_mean_absolute_error: 0.2094 - 515ms/epoch - 16ms/step
# Epoch 309/3000
# 33/33 - 1s - loss: 0.0657 - mean_absolute_error: 0.0657 - val_loss: 0.1857 - val_mean_absolute_error: 0.1857 - 537ms/epoch - 16ms/step
# Epoch 310/3000
# 33/33 - 1s - loss: 0.0568 - mean_absolute_error: 0.0568 - val_loss: 0.1840 - val_mean_absolute_error: 0.1840 - 509ms/epoch - 15ms/step
# Epoch 311/3000
# 33/33 - 1s - loss: 0.0571 - mean_absolute_error: 0.0571 - val_loss: 0.1850 - val_mean_absolute_error: 0.1850 - 515ms/epoch - 16ms/step
# Epoch 312/3000
# 33/33 - 1s - loss: 0.0603 - mean_absolute_error: 0.0603 - val_loss: 0.1976 - val_mean_absolute_error: 0.1976 - 513ms/epoch - 16ms/step
# Epoch 313/3000
# 33/33 - 1s - loss: 0.0647 - mean_absolute_error: 0.0647 - val_loss: 0.1851 - val_mean_absolute_error: 0.1851 - 511ms/epoch - 15ms/step
# Epoch 314/3000
# 33/33 - 1s - loss: 0.0599 - mean_absolute_error: 0.0599 - val_loss: 0.1847 - val_mean_absolute_error: 0.1847 - 509ms/epoch - 15ms/step
# Epoch 315/3000
# 33/33 - 1s - loss: 0.0599 - mean_absolute_error: 0.0599 - val_loss: 0.1948 - val_mean_absolute_error: 0.1948 - 510ms/epoch - 15ms/step
# Epoch 316/3000
# 33/33 - 1s - loss: 0.0711 - mean_absolute_error: 0.0711 - val_loss: 0.1852 - val_mean_absolute_error: 0.1852 - 529ms/epoch - 16ms/step
# Epoch 317/3000
# 33/33 - 1s - loss: 0.0591 - mean_absolute_error: 0.0591 - val_loss: 0.2002 - val_mean_absolute_error: 0.2002 - 505ms/epoch - 15ms/step
# Epoch 318/3000
# 33/33 - 1s - loss: 0.0583 - mean_absolute_error: 0.0583 - val_loss: 0.1862 - val_mean_absolute_error: 0.1862 - 512ms/epoch - 16ms/step
# Epoch 319/3000
# 33/33 - 1s - loss: 0.0602 - mean_absolute_error: 0.0602 - val_loss: 0.1789 - val_mean_absolute_error: 0.1789 - 521ms/epoch - 16ms/step
# Epoch 320/3000
# 33/33 - 1s - loss: 0.0656 - mean_absolute_error: 0.0656 - val_loss: 0.2000 - val_mean_absolute_error: 0.2000 - 505ms/epoch - 15ms/step
# Epoch 321/3000
# ...
# Epoch 412/3000
# 33/33 - 1s - loss: 0.0479 - mean_absolute_error: 0.0479 - val_loss: 0.1858 - val_mean_absolute_error: 0.1858 - 929ms/epoch - 28ms/step
# Epoch 413/3000
# 33/33 - 1s - loss: 0.0527 - mean_absolute_error: 0.0527 - val_loss: 0.1894 - val_mean_absolute_error: 0.1894 - 924ms/epoch - 28ms/step
# Epoch 414/3000
# 33/33 - 1s - loss: 0.0643 - mean_absolute_error: 0.0643 - val_loss: 0.1902 - val_mean_absolute_error: 0.1902 - 1s/epoch - 33ms/step
# Epoch 415/3000
# 33/33 - 1s - loss: 0.0481 - mean_absolute_error: 0.0481 - val_loss: 0.1856 - val_mean_absolute_error: 0.1856 - 1s/epoch - 33ms/step
# Epoch 416/3000
# 33/33 - 1s - loss: 0.0465 - mean_absolute_error: 0.0465 - val_loss: 0.1834 - val_mean_absolute_error: 0.1834 - 956ms/epoch - 29ms/step
# Epoch 417/3000
# 33/33 - 1s - loss: 0.0471 - mean_absolute_error: 0.0471 - val_loss: 0.1746 - val_mean_absolute_error: 0.1746 - 1s/epoch - 33ms/step
# Epoch 418/3000
# 33/33 - 1s - loss: 0.0456 - mean_absolute_error: 0.0456 - val_loss: 0.1800 - val_mean_absolute_error: 0.1800 - 973ms/epoch - 29ms/step
# Epoch 419/3000
# 33/33 - 1s - loss: 0.0508 - mean_absolute_error: 0.0508 - val_loss: 0.1933 - val_mean_absolute_error: 0.1933 - 1s/epoch - 30ms/step
# Epoch 420/3000
# 33/33 - 1s - loss: 0.0501 - mean_absolute_error: 0.0501 - val_loss: 0.1831 - val_mean_absolute_error: 0.1831 - 1s/epoch - 32ms/step
# Epoch 421/3000
# 33/33 - 1s - loss: 0.0481 - mean_absolute_error: 0.0481 - val_loss: 0.1875 - val_mean_absolute_error: 0.1875 - 1s/epoch - 40ms/step
# Epoch 422/3000
# 33/33 - 1s - loss: 0.0479 - mean_absolute_error: 0.0479 - val_loss: 0.1825 - val_mean_absolute_error: 0.1825 - 1s/epoch - 33ms/step
# Epoch 423/3000
# 33/33 - 1s - loss: 0.0485 - mean_absolute_error: 0.0485 - val_loss: 0.1959 - val_mean_absolute_error: 0.1959 - 1s/epoch - 34ms/step
# Epoch 424/3000
# 33/33 - 1s - loss: 0.0529 - mean_absolute_error: 0.0529 - val_loss: 0.1777 - val_mean_absolute_error: 0.1777 - 1s/epoch - 38ms/step
# Epoch 425/3000
# 33/33 - 1s - loss: 0.0475 - mean_absolute_error: 0.0475 - val_loss: 0.1781 - val_mean_absolute_error: 0.1781 - 904ms/epoch - 27ms/step
# Epoch 426/3000
# 33/33 - 1s - loss: 0.0512 - mean_absolute_error: 0.0512 - val_loss: 0.1957 - val_mean_absolute_error: 0.1957 - 573ms/epoch - 17ms/step
# Epoch 427/3000
# 33/33 - 1s - loss: 0.0607 - mean_absolute_error: 0.0607 - val_loss: 0.2054 - val_mean_absolute_error: 0.2054 - 539ms/epoch - 16ms/step
# Epoch 428/3000
# 33/33 - 1s - loss: 0.0543 - mean_absolute_error: 0.0543 - val_loss: 0.1858 - val_mean_absolute_error: 0.1858 - 526ms/epoch - 16ms/step
# Epoch 429/3000
# 33/33 - 0s - loss: 0.0473 - mean_absolute_error: 0.0473 - val_loss: 0.1785 - val_mean_absolute_error: 0.1785 - 498ms/epoch - 15ms/step
# Epoch 430/3000
# 33/33 - 1s - loss: 0.0497 - mean_absolute_error: 0.0497 - val_loss: 0.1842 - val_mean_absolute_error: 0.1842 - 521ms/epoch - 16ms/step
# Epoch 431/3000
# 33/33 - 1s - loss: 0.0542 - mean_absolute_error: 0.0542 - val_loss: 0.1900 - val_mean_absolute_error: 0.1900 - 613ms/epoch - 19ms/step
# Epoch 432/3000
# 33/33 - 1s - loss: 0.0503 - mean_absolute_error: 0.0503 - val_loss: 0.1914 - val_mean_absolute_error: 0.1914 - 514ms/epoch - 16ms/step
# Epoch 433/3000
# 33/33 - 0s - loss: 0.0459 - mean_absolute_error: 0.0459 - val_loss: 0.1793 - val_mean_absolute_error: 0.1793 - 486ms/epoch - 15ms/step
# Epoch 434/3000
# 33/33 - 0s - loss: 0.0462 - mean_absolute_error: 0.0462 - val_loss: 0.1946 - val_mean_absolute_error: 0.1946 - 483ms/epoch - 15ms/step
# Epoch 435/3000
# 33/33 - 0s - loss: 0.0533 - mean_absolute_error: 0.0533 - val_loss: 0.1817 - val_mean_absolute_error: 0.1817 - 492ms/epoch - 15ms/step
# Epoch 436/3000
# 33/33 - 1s - loss: 0.0478 - mean_absolute_error: 0.0478 - val_loss: 0.1834 - val_mean_absolute_error: 0.1834 - 501ms/epoch - 15ms/step
# Epoch 437/3000
# 33/33 - 1s - loss: 0.0460 - mean_absolute_error: 0.0460 - val_loss: 0.1812 - val_mean_absolute_error: 0.1812 - 622ms/epoch - 19ms/step
# Epoch 438/3000
# 33/33 - 1s - loss: 0.0509 - mean_absolute_error: 0.0509 - val_loss: 0.1800 - val_mean_absolute_error: 0.1800 - 513ms/epoch - 16ms/step
# Epoch 439/3000
# 33/33 - 1s - loss: 0.0513 - mean_absolute_error: 0.0513 - val_loss: 0.1846 - val_mean_absolute_error: 0.1846 - 543ms/epoch - 16ms/step
# Epoch 440/3000
# 33/33 - 0s - loss: 0.0515 - mean_absolute_error: 0.0515 - val_loss: 0.1813 - val_mean_absolute_error: 0.1813 - 496ms/epoch - 15ms/step
# Epoch 441/3000
# 33/33 - 0s - loss: 0.0499 - mean_absolute_error: 0.0499 - val_loss: 0.1880 - val_mean_absolute_error: 0.1880 - 499ms/epoch - 15ms/step
# Epoch 442/3000
# 33/33 - 0s - loss: 0.0510 - mean_absolute_error: 0.0510 - val_loss: 0.1782 - val_mean_absolute_error: 0.1782 - 495ms/epoch - 15ms/step
# Epoch 443/3000
# 33/33 - 0s - loss: 0.0499 - mean_absolute_error: 0.0499 - val_loss: 0.1884 - val_mean_absolute_error: 0.1884 - 493ms/epoch - 15ms/step
# Epoch 444/3000
# 33/33 - 1s - loss: 0.0526 - mean_absolute_error: 0.0526 - val_loss: 0.2058 - val_mean_absolute_error: 0.2058 - 526ms/epoch - 16ms/step
# Epoch 445/3000
# 33/33 - 1s - loss: 0.0664 - mean_absolute_error: 0.0664 - val_loss: 0.1991 - val_mean_absolute_error: 0.1991 - 550ms/epoch - 17ms/step
# Epoch 446/3000
# 33/33 - 1s - loss: 0.0532 - mean_absolute_error: 0.0532 - val_loss: 0.1848 - val_mean_absolute_error: 0.1848 - 535ms/epoch - 16ms/step
# Epoch 447/3000
# 33/33 - 1s - loss: 0.0494 - mean_absolute_error: 0.0494 - val_loss: 0.1768 - val_mean_absolute_error: 0.1768 - 527ms/epoch - 16ms/step
# Epoch 448/3000
# 33/33 - 0s - loss: 0.0500 - mean_absolute_error: 0.0500 - val_loss: 0.1790 - val_mean_absolute_error: 0.1790 - 491ms/epoch - 15ms/step
# Epoch 449/3000
# 33/33 - 1s - loss: 0.0480 - mean_absolute_error: 0.0480 - val_loss: 0.1835 - val_mean_absolute_error: 0.1835 - 526ms/epoch - 16ms/step
# Epoch 450/3000
# 33/33 - 1s - loss: 0.0472 - mean_absolute_error: 0.0472 - val_loss: 0.1805 - val_mean_absolute_error: 0.1805 - 514ms/epoch - 16ms/step
# Epoch 451/3000
# 33/33 - 1s - loss: 0.0454 - mean_absolute_error: 0.0454 - val_loss: 0.1869 - val_mean_absolute_error: 0.1869 - 511ms/epoch - 15ms/step
# Epoch 452/3000
# 33/33 - 0s - loss: 0.0491 - mean_absolute_error: 0.0491 - val_loss: 0.1833 - val_mean_absolute_error: 0.1833 - 492ms/epoch - 15ms/step
# Epoch 453/3000
# 33/33 - 0s - loss: 0.0461 - mean_absolute_error: 0.0461 - val_loss: 0.1852 - val_mean_absolute_error: 0.1852 - 491ms/epoch - 15ms/step
# Epoch 454/3000
# 33/33 - 1s - loss: 0.0507 - mean_absolute_error: 0.0507 - val_loss: 0.1834 - val_mean_absolute_error: 0.1834 - 515ms/epoch - 16ms/step
# Epoch 455/3000
# 33/33 - 1s - loss: 0.0522 - mean_absolute_error: 0.0522 - val_loss: 0.1854 - val_mean_absolute_error: 0.1854 - 504ms/epoch - 15ms/step
# Epoch 456/3000
# 33/33 - 0s - loss: 0.0490 - mean_absolute_error: 0.0490 - val_loss: 0.1795 - val_mean_absolute_error: 0.1795 - 493ms/epoch - 15ms/step
# Epoch 457/3000
# 33/33 - 1s - loss: 0.0505 - mean_absolute_error: 0.0505 - val_loss: 0.1855 - val_mean_absolute_error: 0.1855 - 520ms/epoch - 16ms/step
# Epoch 458/3000
# 33/33 - 1s - loss: 0.0450 - mean_absolute_error: 0.0450 - val_loss: 0.1840 - val_mean_absolute_error: 0.1840 - 523ms/epoch - 16ms/step
# Epoch 459/3000
# 33/33 - 1s - loss: 0.0502 - mean_absolute_error: 0.0502 - val_loss: 0.2026 - val_mean_absolute_error: 0.2026 - 517ms/epoch - 16ms/step
# Epoch 460/3000
# 33/33 - 0s - loss: 0.0515 - mean_absolute_error: 0.0515 - val_loss: 0.1917 - val_mean_absolute_error: 0.1917 - 490ms/epoch - 15ms/step
# Epoch 461/3000
# 33/33 - 1s - loss: 0.0498 - mean_absolute_error: 0.0498 - val_loss: 0.1762 - val_mean_absolute_error: 0.1762 - 527ms/epoch - 16ms/step
# Epoch 462/3000
# 33/33 - 1s - loss: 0.0491 - mean_absolute_error: 0.0491 - val_loss: 0.1852 - val_mean_absolute_error: 0.1852 - 518ms/epoch - 16ms/step
# Epoch 463/3000
# 33/33 - 0s - loss: 0.0468 - mean_absolute_error: 0.0468 - val_loss: 0.1845 - val_mean_absolute_error: 0.1845 - 495ms/epoch - 15ms/step
# Epoch 464/3000
# 33/33 - 1s - loss: 0.0446 - mean_absolute_error: 0.0446 - val_loss: 0.1777 - val_mean_absolute_error: 0.1777 - 502ms/epoch - 15ms/step
# Epoch 465/3000
# 33/33 - 1s - loss: 0.0436 - mean_absolute_error: 0.0436 - val_loss: 0.1907 - val_mean_absolute_error: 0.1907 - 515ms/epoch - 16ms/step
# Epoch 466/3000
# 33/33 - 1s - loss: 0.0459 - mean_absolute_error: 0.0459 - val_loss: 0.1889 - val_mean_absolute_error: 0.1889 - 553ms/epoch - 17ms/step
# Epoch 467/3000
# 33/33 - 0s - loss: 0.0517 - mean_absolute_error: 0.0517 - val_loss: 0.2032 - val_mean_absolute_error: 0.2032 - 488ms/epoch - 15ms/step
# Epoch 468/3000
# 33/33 - 1s - loss: 0.0532 - mean_absolute_error: 0.0532 - val_loss: 0.1831 - val_mean_absolute_error: 0.1831 - 501ms/epoch - 15ms/step
# Epoch 469/3000
# 33/33 - 0s - loss: 0.0470 - mean_absolute_error: 0.0470 - val_loss: 0.1895 - val_mean_absolute_error: 0.1895 - 498ms/epoch - 15ms/step
# Epoch 470/3000
# 33/33 - 0s - loss: 0.0503 - mean_absolute_error: 0.0503 - val_loss: 0.1890 - val_mean_absolute_error: 0.1890 - 472ms/epoch - 14ms/step
# Epoch 471/3000
# 33/33 - 0s - loss: 0.0488 - mean_absolute_error: 0.0488 - val_loss: 0.1808 - val_mean_absolute_error: 0.1808 - 495ms/epoch - 15ms/step
# Epoch 472/3000
# 33/33 - 0s - loss: 0.0458 - mean_absolute_error: 0.0458 - val_loss: 0.1852 - val_mean_absolute_error: 0.1852 - 496ms/epoch - 15ms/step
# Epoch 473/3000
# 33/33 - 1s - loss: 0.0467 - mean_absolute_error: 0.0467 - val_loss: 0.1858 - val_mean_absolute_error: 0.1858 - 517ms/epoch - 16ms/step
# Epoch 474/3000
# 33/33 - 1s - loss: 0.0472 - mean_absolute_error: 0.0472 - val_loss: 0.1830 - val_mean_absolute_error: 0.1830 - 500ms/epoch - 15ms/step
# Epoch 475/3000
# 33/33 - 0s - loss: 0.0478 - mean_absolute_error: 0.0478 - val_loss: 0.1848 - val_mean_absolute_error: 0.1848 - 481ms/epoch - 15ms/step
# Epoch 476/3000
# 33/33 - 0s - loss: 0.0446 - mean_absolute_error: 0.0446 - val_loss: 0.1880 - val_mean_absolute_error: 0.1880 - 491ms/epoch - 15ms/step
# Epoch 477/3000
# 33/33 - 0s - loss: 0.0440 - mean_absolute_error: 0.0440 - val_loss: 0.1837 - val_mean_absolute_error: 0.1837 - 477ms/epoch - 14ms/step
# Epoch 478/3000
# 33/33 - 0s - loss: 0.0459 - mean_absolute_error: 0.0459 - val_loss: 0.1874 - val_mean_absolute_error: 0.1874 - 481ms/epoch - 15ms/step
# Epoch 479/3000
# 33/33 - 0s - loss: 0.0495 - mean_absolute_error: 0.0495 - val_loss: 0.1822 - val_mean_absolute_error: 0.1822 - 492ms/epoch - 15ms/step
# Epoch 480/3000
# 33/33 - 1s - loss: 0.0473 - mean_absolute_error: 0.0473 - val_loss: 0.1874 - val_mean_absolute_error: 0.1874 - 565ms/epoch - 17ms/step
# Epoch 481/3000
# 33/33 - 1s - loss: 0.0563 - mean_absolute_error: 0.0563 - val_loss: 0.1853 - val_mean_absolute_error: 0.1853 - 504ms/epoch - 15ms/step
# Epoch 482/3000
# 33/33 - 0s - loss: 0.0456 - mean_absolute_error: 0.0456 - val_loss: 0.1849 - val_mean_absolute_error: 0.1849 - 481ms/epoch - 15ms/step
# Epoch 483/3000
# 33/33 - 0s - loss: 0.0449 - mean_absolute_error: 0.0449 - val_loss: 0.1807 - val_mean_absolute_error: 0.1807 - 472ms/epoch - 14ms/step
# Epoch 484/3000
# 33/33 - 0s - loss: 0.0425 - mean_absolute_error: 0.0425 - val_loss: 0.2018 - val_mean_absolute_error: 0.2018 - 477ms/epoch - 14ms/step
# Epoch 485/3000
# 33/33 - 0s - loss: 0.0488 - mean_absolute_error: 0.0488 - val_loss: 0.1821 - val_mean_absolute_error: 0.1821 - 482ms/epoch - 15ms/step
# Epoch 486/3000
# 33/33 - 1s - loss: 0.0483 - mean_absolute_error: 0.0483 - val_loss: 0.1925 - val_mean_absolute_error: 0.1925 - 518ms/epoch - 16ms/step
# Epoch 487/3000
# 33/33 - 0s - loss: 0.0469 - mean_absolute_error: 0.0469 - val_loss: 0.1844 - val_mean_absolute_error: 0.1844 - 493ms/epoch - 15ms/step
# Epoch 488/3000
# 33/33 - 0s - loss: 0.0431 - mean_absolute_error: 0.0431 - val_loss: 0.1966 - val_mean_absolute_error: 0.1966 - 481ms/epoch - 15ms/step
# Epoch 489/3000
# 33/33 - 1s - loss: 0.0484 - mean_absolute_error: 0.0484 - val_loss: 0.2064 - val_mean_absolute_error: 0.2064 - 510ms/epoch - 15ms/step
# Epoch 490/3000
# 33/33 - 0s - loss: 0.0581 - mean_absolute_error: 0.0581 - val_loss: 0.2073 - val_mean_absolute_error: 0.2073 - 486ms/epoch - 15ms/step
# Epoch 491/3000
# 33/33 - 0s - loss: 0.0469 - mean_absolute_error: 0.0469 - val_loss: 0.1788 - val_mean_absolute_error: 0.1788 - 487ms/epoch - 15ms/step
# Epoch 492/3000
# 33/33 - 0s - loss: 0.0424 - mean_absolute_error: 0.0424 - val_loss: 0.1892 - val_mean_absolute_error: 0.1892 - 480ms/epoch - 15ms/step
# Epoch 493/3000
# 33/33 - 0s - loss: 0.0449 - mean_absolute_error: 0.0449 - val_loss: 0.1828 - val_mean_absolute_error: 0.1828 - 482ms/epoch - 15ms/step
# Epoch 494/3000
# 33/33 - 0s - loss: 0.0494 - mean_absolute_error: 0.0494 - val_loss: 0.1879 - val_mean_absolute_error: 0.1879 - 489ms/epoch - 15ms/step
# Epoch 495/3000
# 33/33 - 0s - loss: 0.0476 - mean_absolute_error: 0.0476 - val_loss: 0.1908 - val_mean_absolute_error: 0.1908 - 475ms/epoch - 14ms/step
# Epoch 496/3000
# 33/33 - 0s - loss: 0.0508 - mean_absolute_error: 0.0508 - val_loss: 0.1803 - val_mean_absolute_error: 0.1803 - 488ms/epoch - 15ms/step
# Epoch 497/3000
# 33/33 - 1s - loss: 0.0499 - mean_absolute_error: 0.0499 - val_loss: 0.1861 - val_mean_absolute_error: 0.1861 - 529ms/epoch - 16ms/step
# Epoch 498/3000
# 33/33 - 1s - loss: 0.0445 - mean_absolute_error: 0.0445 - val_loss: 0.1822 - val_mean_absolute_error: 0.1822 - 1s/epoch - 32ms/step
# Epoch 499/3000
# 33/33 - 1s - loss: 0.0453 - mean_absolute_error: 0.0453 - val_loss: 0.1885 - val_mean_absolute_error: 0.1885 - 1s/epoch - 38ms/step
# Epoch 500/3000
# 33/33 - 2s - loss: 0.0418 - mean_absolute_error: 0.0418 - val_loss: 0.1892 - val_mean_absolute_error: 0.1892 - 2s/epoch - 49ms/step
# Epoch 501/3000
# 33/33 - 1s - loss: 0.0656 - mean_absolute_error: 0.0656 - val_loss: 0.1944 - val_mean_absolute_error: 0.1944 - 1s/epoch - 38ms/step
# Epoch 502/3000
# 33/33 - 1s - loss: 0.0563 - mean_absolute_error: 0.0563 - val_loss: 0.1856 - val_mean_absolute_error: 0.1856 - 1s/epoch - 34ms/step
# Epoch 503/3000
# 33/33 - 1s - loss: 0.0518 - mean_absolute_error: 0.0518 - val_loss: 0.1813 - val_mean_absolute_error: 0.1813 - 1s/epoch - 34ms/step
# Epoch 504/3000
# 33/33 - 1s - loss: 0.0432 - mean_absolute_error: 0.0432 - val_loss: 0.1852 - val_mean_absolute_error: 0.1852 - 1s/epoch - 34ms/step
# Epoch 505/3000
# 33/33 - 1s - loss: 0.0444 - mean_absolute_error: 0.0444 - val_loss: 0.1889 - val_mean_absolute_error: 0.1889 - 1s/epoch - 37ms/step
# Epoch 506/3000
# 33/33 - 1s - loss: 0.0444 - mean_absolute_error: 0.0444 - val_loss: 0.1857 - val_mean_absolute_error: 0.1857 - 1s/epoch - 41ms/step
# Epoch 507/3000
# 33/33 - 1s - loss: 0.0463 - mean_absolute_error: 0.0463 - val_loss: 0.1892 - val_mean_absolute_error: 0.1892 - 1s/epoch - 44ms/step
# Epoch 508/3000
# 33/33 - 1s - loss: 0.0573 - mean_absolute_error: 0.0573 - val_loss: 0.1849 - val_mean_absolute_error: 0.1849 - 1s/epoch - 38ms/step
# Epoch 509/3000
# 33/33 - 1s - loss: 0.0505 - mean_absolute_error: 0.0505 - val_loss: 0.1991 - val_mean_absolute_error: 0.1991 - 1s/epoch - 31ms/step
# Epoch 510/3000
# 33/33 - 1s - loss: 0.0474 - mean_absolute_error: 0.0474 - val_loss: 0.1760 - val_mean_absolute_error: 0.1760 - 1s/epoch - 31ms/step
# Epoch 511/3000
# 33/33 - 1s - loss: 0.0428 - mean_absolute_error: 0.0428 - val_loss: 0.1959 - val_mean_absolute_error: 0.1959 - 942ms/epoch - 29ms/step
# Epoch 512/3000
# 33/33 - 1s - loss: 0.0545 - mean_absolute_error: 0.0545 - val_loss: 0.1938 - val_mean_absolute_error: 0.1938 - 903ms/epoch - 27ms/step
# Epoch 513/3000
# 33/33 - 1s - loss: 0.0453 - mean_absolute_error: 0.0453 - val_loss: 0.1868 - val_mean_absolute_error: 0.1868 - 967ms/epoch - 29ms/step
# Epoch 514/3000
# 33/33 - 1s - loss: 0.0464 - mean_absolute_error: 0.0464 - val_loss: 0.1838 - val_mean_absolute_error: 0.1838 - 922ms/epoch - 28ms/step
# Epoch 515/3000
# 33/33 - 1s - loss: 0.0438 - mean_absolute_error: 0.0438 - val_loss: 0.1918 - val_mean_absolute_error: 0.1918 - 937ms/epoch - 28ms/step
# Epoch 516/3000
# 33/33 - 1s - loss: 0.0447 - mean_absolute_error: 0.0447 - val_loss: 0.1828 - val_mean_absolute_error: 0.1828 - 931ms/epoch - 28ms/step
# Epoch 517/3000
# Restoring model weights from the end of the best epoch: 417.
# 33/33 - 1s - loss: 0.0475 - mean_absolute_error: 0.0475 - val_loss: 0.1804 - val_mean_absolute_error: 0.1804 - 1s/epoch - 33ms/step
# Epoch 517: early stopping
# CPU times: user 27min 33s, sys: 3min 53s, total: 31min 26s
# Wall time: 5min 9s

# %%
pred=model.predict(X_test)
print(mean_absolute_error(y_test,pred))
# Out:
# 11/11 [==============================] - 0s 5ms/step
# 0.2015130918164431

# %%
#f=open('SinglePropertyPrediction-test-formula_energy-ssub-AI-mae.csv','w')
f=open('AI-SinglePropertyPrediction-formula_energy-ssub-test-mae.csv','w')
f.write('id,target,prediction\n')
for i,j,k in zip(test_ids,y_test,pred):
    line=str(i)+','+str(j)+','+str(k)+'\n'
    f.write(line)
f.close()

# %%
import os
cmd = 'zip AI-SinglePropertyPrediction-formula_energy-ssub-test-mae.csv.zip AI-SinglePropertyPrediction-formula_energy-ssub-test-mae.csv'
os.system(cmd)
# Out:
# updating: AI-SinglePropertyPrediction-formula_energy-ssub-test-mae.csv (deflated 54%)
# 0
